# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# Out:
# 2024-12-26 13:08:55.196099: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-26 13:08:55.196159: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-26 13:08:55.196194: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-26 13:08:55.204495: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !pip install --upgrade matplotlib seaborn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/work/.local/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /home/work/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.3.post1)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.losses import mse, binary_crossentropy, kl_divergence
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import scale


import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('../newKDDTrain+.txt', header=None)

columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
train_df.columns = columns

train_df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate    class
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  anomaly
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
test_df = pd.read_csv('../newKDDTest+.txt', header=None)

test_columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
test_df.columns = columns

test_df.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  86
# 3               0       0    0  ...                  57
# 4               0       0    0  ...                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate    class
# 0                      1.00  anomaly
# 1                      1.00  anomaly
# 2                      0.00   normal
# 3                      0.00  anomaly
# 4                      0.71  anomaly
#
# [5 rows x 42 columns]

# %%
df = pd.concat([train_df, test_df])

# %%
df['class']
# Out:
# 0         normal
# 1         normal
# 2        anomaly
# 3         normal
# 4         normal
#           ...
# 22539     normal
# 22540     normal
# 22541    anomaly
# 22542     normal
# 22543    anomaly
# Name: class, Length: 148517, dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
len(df.columns)
# Out:
# 42

# %%
df.shape
# Out:
# (148517, 42)

# %%
# 'label' 열의 값이 'normal.'이면 0으로, 'normal.'이 아니면 1로 변경
df['class'] = df['class'].apply(lambda x: 0 if x == 'normal' else 1)

# 변경된 데이터프레임 확인
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding 적용
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['service'] = label_encoder.fit_transform(df['service'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# 인코딩된 데이터프레임 확인
print(df.head())
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       20     9        491          0     0
# 1         0              2       44     9        146          0     0
# 2         0              1       49     5          0          0     0
# 3         0              1       24     9        232       8153     0
# 4         0              1       24     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (148517, 42)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

tmp = df.drop(labels = 'class',axis=1)
labels = df['class']

# 1. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(tmp)

# 2. PCA 적용 (주성분 개수 설정)
n_components = 20  # 원하는 차원 수로 설정
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)


# 3. PCA 누적 분산 비율 확인
explained_variance_ratio = pca.explained_variance_ratio_.cumsum()
print("누적 분산 비율 (cumulative explained variance):")
print(explained_variance_ratio)

# 4. PCA 결과를 DataFrame으로 변환하고 label 병합
X_pca_df = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(n_components)])
df_merged = X_pca_df.assign(label=labels.values)

# 열 이름 변경 (label -> class)
df_merged.rename(columns={'label': 'class'}, inplace=True)


# 5. 병합된 데이터 타입 확인
print("Label 데이터 타입:", df_merged['class'].dtype)

# 6. 정렬 여부 확인 (필요하면 추가)
# 확인 예시: 병합 전후 `labels` 순서와 `df_merged['label']`이 동일한지 점검
assert np.array_equal(labels.values, df_merged['class'].values), "Label 순서가 일치하지 않습니다."

# 7. PCA 결과 시각화 (2D로 줄인 경우)
import matplotlib.pyplot as plt
if n_components >= 2:
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.5)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title('PCA 결과 시각화')
    plt.colorbar(label='Label')
    plt.show()
# Out:
# 누적 분산 비율 (cumulative explained variance):
# [0.18919362 0.317851   0.38738707 0.43961021 0.4865     0.52882691
#  0.5676753  0.60102599 0.62934356 0.65603097 0.68175274 0.70731433
#  0.73231683 0.75726586 0.78210081 0.80684803 0.83054577 0.85362758
#  0.87282535 0.89117939 0.90691815 0.92178925]
# Label 데이터 타입: int64
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#엘보우 방법
import matplotlib.pyplot as plt

# 각 주성분의 분산 비율
explained_variance_ratio = pca.explained_variance_ratio_

# 시각화
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
# 누적 분산 비율 계산
cumulative_variance_ratio = pca.explained_variance_ratio_.cumsum()

# 누적 분산 비율 출력
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance Ratio')
plt.grid()
plt.show()

# %%
# X_pca를 DataFrame으로 변환
X_pca_df = pd.DataFrame(X_pca)

# `assign`으로 label 추가
df_merged = X_pca_df.assign(label=df['class'].values)

# %%
df = df_merged

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.937416 -0.099287 -0.033490  0.114524 -0.112027  0.446329 -0.370812
# 1  0.685951  0.530801  0.084341 -0.314058  0.079050  2.454922 -3.183681
# 2  3.557238 -2.531658  0.044006  0.309697 -0.259196 -0.446973 -0.130155
# 3 -2.613555 -0.501687 -0.070456  0.034864 -0.304282 -1.015089  0.093341
# 4 -2.403517 -0.363544 -0.127620 -1.076496  0.106070 -0.662833  0.163658
#
#           7         8         9  ...        13        14        15        16  \
# 0  0.123427  0.165006  0.209004  ...  0.000615 -0.109297  0.113774 -0.159947
# 1  0.747463 -0.687932 -0.280943  ...  0.162899  0.154000 -0.076354 -0.262961
# 2  0.014140  0.166662  0.091615  ... -0.057547 -0.047806  0.020766 -0.031116
# 3  0.047633  0.012300 -0.235640  ...  0.056808  0.042843  0.049509 -0.147943
# 4 -0.015152 -0.018131 -0.343138  ...  0.033182  0.103210 -0.095108 -0.034632
#
#          17        18        19        20        21  label
# 0 -0.213405  0.607710 -0.289683 -0.154773  0.252368      0
# 1 -0.348119  1.279232  0.371991 -1.344458  0.561115      0
# 2 -0.034064 -0.207688  0.118236 -0.291444  0.043778      1
# 3 -0.022229  0.199028 -0.887820 -0.019916 -0.091843      0
# 4  0.016426 -0.411946 -0.088895  0.453858 -0.088159      0
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df, test_size=0.1, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((133665, 23), (14852, 23))

# %%
X_train_normal = X_train[X_train['label'] == 0]
X_train_normal.shape

X_test_normal = X_test[X_test['label'] == 0]
X_test_normal.shape
# Out:
# (7720, 23)

# %%
y_train_normal = X_train_normal['label']
X_train_normal = X_train_normal.drop(labels='label',axis=1)

y_test_normal = X_test_normal['label']
X_test_normal = X_test_normal.drop(labels='label',axis=1)

# %%
y_test = X_test['label']
X_test = X_test.drop(labels='label', axis=1)

# %%
# !pip install keras_self_attention
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_self_attention in /home/work/.local/lib/python3.10/site-packages (0.51.0)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (from keras_self_attention) (1.26.4)

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector, Conv1D, Conv1DTranspose
from keras.models import Model
from keras import regularizers
from keras_self_attention import SeqWeightedAttention, SeqSelfAttention
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
from tensorflow.keras import layers, losses, Model, Input
import numpy as np
from tensorflow.keras import backend as K

latent_dim = 10
inter_dim = 20

# Sampling function for reparameterization trick
def sampling(args):
    z_mean, z_log_sigma = args
    batch_size = tf.shape(z_mean)[0]
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=1.)
    return z_mean + z_log_sigma * epsilon

def vae_loss(x, x_decoded_mean, z_mean, z_log_sigma):
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean), axis=1)
    kl_loss = -0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma), axis=-1)
    kl_loss_weighted = kl_loss * 0.001  # KL 다이버전스 손실에 가중치 부여
    total_loss = K.mean(reconstruction_loss + kl_loss_weighted)
    return total_loss

def cvae(X, labels):
    features = X.shape[1]  # 2D 데이터이므로 timesteps는 필요 없고, features만 사용
    input_x = Input(shape=(features,), name='InputFeatures')  # 2D 입력 (샘플, 특징)

    input_label = Input(shape=(1,), name='InputLabel')  # Assumes binary or multi-class label

    # Embed the label into the same shape as the input
    embedded_label = layers.Embedding(input_dim=2, output_dim=features)(input_label)  # Adjust output_dim to match features
    embedded_label = layers.Flatten()(embedded_label)

    # Concatenate input_x and embedded_label
    concatenated_input = layers.Concatenate()([input_x, embedded_label])

    # Reshape for Conv1D layer (to 3D)
    reshaped_input = layers.Reshape((features + embedded_label.shape[-1], 1))(concatenated_input)

    # Encoder with CNN layers
    h = layers.Conv1D(filters=64, kernel_size=3, activation="relu", padding='same')(reshaped_input)
    h = layers.Conv1D(filters=32, kernel_size=3, activation="relu", padding='same')(h)
    h = layers.Conv1D(filters=16, kernel_size=3, activation="relu", padding='same')(h)

    # Flatten for dense layers (MLP)
    h = layers.Flatten()(h)
    h = layers.Dense(inter_dim, activation='relu')(h)
    h = layers.Dense(inter_dim, activation='relu')(h)

    # z layer
    z_mean = layers.Dense(latent_dim)(h)
    z_log_sigma = layers.Dense(latent_dim)(h)
    z = layers.Lambda(sampling)([z_mean, z_log_sigma])

    # Decoder
    # Add the label to the latent space z
    z_with_label = layers.Concatenate()([z, embedded_label])

    # Expand for Conv1DTranspose layer
    decoder1 = layers.Dense((features + embedded_label.shape[-1]) * inter_dim)(z_with_label)
    decoder1 = layers.Reshape((features + embedded_label.shape[-1], inter_dim))(decoder1)

    # Decoder with CNN layers
    decoder1 = layers.Conv1DTranspose(filters=16, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=32, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=64, kernel_size=3, activation="relu", padding='same')(decoder1)

    # Flatten and final dense layer to reconstruct original features
    decoder1 = layers.Flatten()(decoder1)
    decoder1 = layers.Dense(features)(decoder1)
    
    model = Model([input_x, input_label], decoder1)
    model.add_loss(vae_loss(input_x, decoder1, z_mean, z_log_sigma))
    
    return model

# Create CVAE model
model = cvae(X_train_normal, y_train_normal)
model.summary()

# Compile and train the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy'])
history = model.fit([X_train_normal, y_train_normal], X_train_normal,
                    shuffle=True,
                    epochs=200, 
                    validation_split=0.1,  
                    batch_size=32).history
# Out:
# 2024-12-26 13:09:12.165492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:c8:00.0, compute capability: 8.0
# 2024-12-26 13:09:12.167849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38698 MB memory:  -> device: 1, name: CUDA GPU, pci bus id: 0000:cc:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  InputLabel (InputLayer)     [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 22)                44        ['InputLabel[0][0]']
#
#  InputFeatures (InputLayer)  [(None, 22)]                 0         []
#
#  flatten (Flatten)           (None, 22)                   0         ['embedding[0][0]']
#
#  concatenate (Concatenate)   (None, 44)                   0         ['InputFeatures[0][0]',
#                                                                      'flatten[0][0]']
#
#  reshape (Reshape)           (None, 44, 1)                0         ['concatenate[0][0]']
#
#  conv1d (Conv1D)             (None, 44, 64)               256       ['reshape[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 44, 32)               6176      ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 44, 16)               1552      ['conv1d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 704)                  0         ['conv1d_2[0][0]']
#
#  dense (Dense)               (None, 20)                   14100     ['flatten_1[0][0]']
#
#  dense_1 (Dense)             (None, 20)                   420       ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 10)                   0         ['dense_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32)                   0         ['lambda[0][0]',
#  )                                                                   'flatten[0][0]']
#
#  dense_4 (Dense)             (None, 880)                  29040     ['concatenate_1[0][0]']
#
#  reshape_1 (Reshape)         (None, 44, 20)               0         ['dense_4[0][0]']
#
#  conv1d_transpose (Conv1DTr  (None, 44, 16)               976       ['reshape_1[0][0]']
#  anspose)
#
#  conv1d_transpose_1 (Conv1D  (None, 44, 32)               1568      ['conv1d_transpose[0][0]']
#  Transpose)
#
#  conv1d_transpose_2 (Conv1D  (None, 44, 64)               6208      ['conv1d_transpose_1[0][0]']
#  Transpose)
#
#  flatten_2 (Flatten)         (None, 2816)                 0         ['conv1d_transpose_2[0][0]']
#
#  dense_5 (Dense)             (None, 22)                   61974     ['flatten_2[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['dense_3[0][0]']
#  Lambda)
#
#  tf.math.square_1 (TFOpLamb  (None, 10)                   0         ['dense_2[0][0]']
#  da)
#
#  tf.math.subtract_1 (TFOpLa  (None, 10)                   0         ['tf.__operators__.add[0][0]',
#  mbda)                                                               'tf.math.square_1[0][0]']
#
#  tf.math.exp (TFOpLambda)    (None, 10)                   0         ['dense_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 10)                   0         ['tf.math.subtract_1[0][0]',
#  mbda)                                                               'tf.math.exp[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 22)                   0         ['InputFeatures[0][0]',
#  da)                                                                 'dense_5[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None,)                      0         ['tf.math.subtract_2[0][0]']
#  Lambda)
#
#  tf.math.square (TFOpLambda  (None, 22)                   0         ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.math.reduce_sum_1[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLa  (None,)                      0         ['tf.math.square[0][0]']
#  mbda)
#
#  tf.math.multiply_1 (TFOpLa  (None,)                      0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.__operators__.add_1 (TF  (None,)                      0         ['tf.math.reduce_sum[0][0]',
#  OpLambda)                                                           'tf.math.multiply_1[0][0]']
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.__operators__.add_1[0][0]
#  ambda)                                                             ']
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 122734 (479.43 KB)
# Trainable params: 122734 (479.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 2024-12-26 13:09:14.410097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-12-26 13:09:14.996969: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f65d504b430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-26 13:09:14.997017: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2024-12-26 13:09:14.997024: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): CUDA GPU, Compute Capability 8.0
# 2024-12-26 13:09:15.001654: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-26 13:09:15.079316: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1950/1950 [==============================] - 15s 6ms/step - loss: 12.6297 - accuracy: 0.5769 - val_loss: 3.5410 - val_accuracy: 0.7127
# Epoch 2/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 9.7608 - accuracy: 0.7324 - val_loss: 1.3594 - val_accuracy: 0.7286
# Epoch 3/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2343058944.0000 - accuracy: 0.7392 - val_loss: 1.2214 - val_accuracy: 0.7661
# Epoch 4/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 6.5048 - accuracy: 0.7461 - val_loss: 1.1746 - val_accuracy: 0.7889
# Epoch 5/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 5.6796 - accuracy: 0.7542 - val_loss: 0.6647 - val_accuracy: 0.8209
# Epoch 6/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.9340 - accuracy: 0.7996 - val_loss: 1.9582 - val_accuracy: 0.7219
# Epoch 7/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.9002 - accuracy: 0.8125 - val_loss: 1.3641 - val_accuracy: 0.7701
# Epoch 8/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.2031 - accuracy: 0.8045 - val_loss: 0.5216 - val_accuracy: 0.8447
# Epoch 9/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.0128 - accuracy: 0.8365 - val_loss: 0.4272 - val_accuracy: 0.8607
# Epoch 10/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6436 - accuracy: 0.8214 - val_loss: 0.5961 - val_accuracy: 0.8011
# Epoch 11/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7403 - accuracy: 0.8294 - val_loss: 0.6282 - val_accuracy: 0.7768
# Epoch 12/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.7189 - accuracy: 0.8383 - val_loss: 0.4542 - val_accuracy: 0.8496
# Epoch 13/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2643 - accuracy: 0.8516 - val_loss: 0.6236 - val_accuracy: 0.8314
# Epoch 14/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5754 - accuracy: 0.8547 - val_loss: 1.0806 - val_accuracy: 0.7592
# Epoch 15/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3484 - accuracy: 0.8420 - val_loss: 0.3527 - val_accuracy: 0.8907
# Epoch 16/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7484 - accuracy: 0.8482 - val_loss: 0.4003 - val_accuracy: 0.8644
# Epoch 17/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.1287 - accuracy: 0.8531 - val_loss: 0.4106 - val_accuracy: 0.8750
# Epoch 18/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5410 - accuracy: 0.8750 - val_loss: 0.3628 - val_accuracy: 0.8956
# Epoch 19/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3010 - accuracy: 0.8700 - val_loss: 0.3026 - val_accuracy: 0.9034
# Epoch 20/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.2771 - accuracy: 0.8749 - val_loss: 0.4794 - val_accuracy: 0.8549
# Epoch 21/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2677 - accuracy: 0.8526 - val_loss: 0.3024 - val_accuracy: 0.8835
# Epoch 22/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5460 - accuracy: 0.8684 - val_loss: 0.3088 - val_accuracy: 0.8815
# Epoch 23/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3448 - accuracy: 0.8740 - val_loss: 0.4401 - val_accuracy: 0.8590
# Epoch 24/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.7471 - accuracy: 0.8672 - val_loss: 0.2974 - val_accuracy: 0.8853
# Epoch 25/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8475 - accuracy: 0.8878 - val_loss: 2.3602 - val_accuracy: 0.6546
# Epoch 26/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6216 - accuracy: 0.8649 - val_loss: 0.5884 - val_accuracy: 0.8787
# Epoch 27/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 4.1694 - accuracy: 0.8724 - val_loss: 0.4867 - val_accuracy: 0.8483
# Epoch 28/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.8344 - accuracy: 0.8685 - val_loss: 0.3100 - val_accuracy: 0.9096
# Epoch 29/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0942 - accuracy: 0.8411 - val_loss: 0.3186 - val_accuracy: 0.8868
# Epoch 30/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.7147 - accuracy: 0.8412 - val_loss: 0.2867 - val_accuracy: 0.9008
# Epoch 31/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4780 - accuracy: 0.8635 - val_loss: 0.6539 - val_accuracy: 0.8618
# Epoch 32/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0685 - accuracy: 0.8494 - val_loss: 0.4312 - val_accuracy: 0.8830
# Epoch 33/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9797 - accuracy: 0.8803 - val_loss: 1.4917 - val_accuracy: 0.7812
# Epoch 34/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5203 - accuracy: 0.8406 - val_loss: 0.2791 - val_accuracy: 0.9040
# Epoch 35/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.0455 - accuracy: 0.8597 - val_loss: 0.4137 - val_accuracy: 0.8780
# Epoch 36/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.9344 - accuracy: 0.8674 - val_loss: 0.3832 - val_accuracy: 0.8669
# Epoch 37/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3782 - accuracy: 0.8629 - val_loss: 0.3304 - val_accuracy: 0.8903
# Epoch 38/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.1544 - accuracy: 0.8580 - val_loss: 0.3476 - val_accuracy: 0.8698
# Epoch 39/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.7783 - accuracy: 0.8602 - val_loss: 0.3121 - val_accuracy: 0.9102
# Epoch 40/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.3155 - accuracy: 0.8532 - val_loss: 0.3343 - val_accuracy: 0.8959
# Epoch 41/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.5313 - accuracy: 0.8703 - val_loss: 0.3934 - val_accuracy: 0.8923
# Epoch 42/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4147 - accuracy: 0.8690 - val_loss: 0.2937 - val_accuracy: 0.9054
# Epoch 43/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.5224 - accuracy: 0.8788 - val_loss: 0.4138 - val_accuracy: 0.8666
# Epoch 44/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.0395 - accuracy: 0.8527 - val_loss: 0.6124 - val_accuracy: 0.8934
# Epoch 45/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0248 - accuracy: 0.8704 - val_loss: 0.4489 - val_accuracy: 0.8496
# Epoch 46/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2505 - accuracy: 0.8797 - val_loss: 0.3826 - val_accuracy: 0.8973
# Epoch 47/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 8.8171 - accuracy: 0.8598 - val_loss: 0.3509 - val_accuracy: 0.8744
# Epoch 48/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0964 - accuracy: 0.8642 - val_loss: 0.5215 - val_accuracy: 0.8628
# Epoch 49/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5618 - accuracy: 0.8708 - val_loss: 0.6162 - val_accuracy: 0.8313
# Epoch 50/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.1877 - accuracy: 0.8611 - val_loss: 0.2594 - val_accuracy: 0.8725
# Epoch 51/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8981 - accuracy: 0.8763 - val_loss: 0.3042 - val_accuracy: 0.8907
# Epoch 52/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4370 - accuracy: 0.8764 - val_loss: 0.3007 - val_accuracy: 0.8941
# Epoch 53/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2143 - accuracy: 0.8695 - val_loss: 0.2941 - val_accuracy: 0.8956
# Epoch 54/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3267 - accuracy: 0.8800 - val_loss: 0.2623 - val_accuracy: 0.8861
# Epoch 55/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8644 - accuracy: 0.8812 - val_loss: 0.7308 - val_accuracy: 0.8825
# Epoch 56/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 4.0603 - accuracy: 0.8771 - val_loss: 0.2737 - val_accuracy: 0.9113
# Epoch 57/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.5304 - accuracy: 0.8876 - val_loss: 0.3626 - val_accuracy: 0.8924
# Epoch 58/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.2709 - accuracy: 0.8831 - val_loss: 0.3571 - val_accuracy: 0.8884
# Epoch 59/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0175 - accuracy: 0.8795 - val_loss: 0.2883 - val_accuracy: 0.9115
# Epoch 60/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2596 - accuracy: 0.8883 - val_loss: 0.4362 - val_accuracy: 0.7773
# Epoch 61/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0003 - accuracy: 0.8729 - val_loss: 0.2311 - val_accuracy: 0.8946
# Epoch 62/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.7333 - accuracy: 0.8575 - val_loss: 0.3249 - val_accuracy: 0.8761
# Epoch 63/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5486 - accuracy: 0.8813 - val_loss: 0.2298 - val_accuracy: 0.9067
# Epoch 64/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7150 - accuracy: 0.8789 - val_loss: 0.2964 - val_accuracy: 0.8934
# Epoch 65/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.9417 - accuracy: 0.8809 - val_loss: 0.2002 - val_accuracy: 0.8907
# Epoch 66/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0201 - accuracy: 0.8881 - val_loss: 0.2041 - val_accuracy: 0.9146
# Epoch 67/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3709 - accuracy: 0.8913 - val_loss: 0.1880 - val_accuracy: 0.8930
# Epoch 68/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1018 - accuracy: 0.8834 - val_loss: 0.2398 - val_accuracy: 0.9019
# Epoch 69/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8644 - accuracy: 0.8984 - val_loss: 0.2030 - val_accuracy: 0.9306
# Epoch 70/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2788 - accuracy: 0.8930 - val_loss: 0.2531 - val_accuracy: 0.9055
# Epoch 71/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0849 - accuracy: 0.8915 - val_loss: 0.2140 - val_accuracy: 0.9143
# Epoch 72/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.3330 - accuracy: 0.8859 - val_loss: 0.2938 - val_accuracy: 0.9084
# Epoch 73/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4156 - accuracy: 0.8896 - val_loss: 0.2397 - val_accuracy: 0.8999
# Epoch 74/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1656 - accuracy: 0.8967 - val_loss: 0.2210 - val_accuracy: 0.9019
# Epoch 75/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3856 - accuracy: 0.8765 - val_loss: 0.3431 - val_accuracy: 0.9034
# Epoch 76/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8732 - accuracy: 0.8983 - val_loss: 0.1604 - val_accuracy: 0.9191
# Epoch 77/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6026 - accuracy: 0.8929 - val_loss: 0.1902 - val_accuracy: 0.9276
# Epoch 78/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8313 - accuracy: 0.8983 - val_loss: 0.1862 - val_accuracy: 0.9253
# Epoch 79/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3385 - accuracy: 0.8950 - val_loss: 0.8254 - val_accuracy: 0.8510
# Epoch 80/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 8.2353 - accuracy: 0.8800 - val_loss: 0.2937 - val_accuracy: 0.9285
# Epoch 81/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7242 - accuracy: 0.9101 - val_loss: 0.3411 - val_accuracy: 0.9162
# Epoch 82/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6325 - accuracy: 0.8910 - val_loss: 0.2331 - val_accuracy: 0.8983
# Epoch 83/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8939 - accuracy: 0.8956 - val_loss: 0.6163 - val_accuracy: 0.9003
# Epoch 84/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5404 - accuracy: 0.8972 - val_loss: 0.1526 - val_accuracy: 0.9145
# Epoch 85/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6638 - accuracy: 0.8926 - val_loss: 0.2344 - val_accuracy: 0.9275
# Epoch 86/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.6086 - accuracy: 0.8791 - val_loss: 0.2296 - val_accuracy: 0.9086
# Epoch 87/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9139 - accuracy: 0.9083 - val_loss: 0.2405 - val_accuracy: 0.9025
# Epoch 88/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.5924 - accuracy: 0.8936 - val_loss: 0.4955 - val_accuracy: 0.8979
# Epoch 89/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5508 - accuracy: 0.8778 - val_loss: 0.2930 - val_accuracy: 0.8915
# Epoch 90/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9523 - accuracy: 0.8904 - val_loss: 0.4740 - val_accuracy: 0.8892
# Epoch 91/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3821 - accuracy: 0.8981 - val_loss: 0.1733 - val_accuracy: 0.9182
# Epoch 92/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8561 - accuracy: 0.8961 - val_loss: 0.1797 - val_accuracy: 0.9169
# Epoch 93/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9795 - accuracy: 0.8943 - val_loss: 0.3027 - val_accuracy: 0.8956
# Epoch 94/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5466 - accuracy: 0.8909 - val_loss: 0.3051 - val_accuracy: 0.8982
# Epoch 95/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.3644 - accuracy: 0.8908 - val_loss: 0.2693 - val_accuracy: 0.9155
# Epoch 96/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.9944 - accuracy: 0.8956 - val_loss: 0.2513 - val_accuracy: 0.9166
# Epoch 97/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9847 - accuracy: 0.8935 - val_loss: 0.2651 - val_accuracy: 0.8660
# Epoch 98/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2241 - accuracy: 0.8895 - val_loss: 0.2103 - val_accuracy: 0.9024
# Epoch 99/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6027 - accuracy: 0.8955 - val_loss: 0.1862 - val_accuracy: 0.9270
# Epoch 100/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6376 - accuracy: 0.8753 - val_loss: 0.3291 - val_accuracy: 0.8665
# Epoch 101/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3522 - accuracy: 0.8710 - val_loss: 0.2883 - val_accuracy: 0.8972
# Epoch 102/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.6120 - accuracy: 0.9077 - val_loss: 0.2169 - val_accuracy: 0.9065
# Epoch 103/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.1326 - accuracy: 0.8954 - val_loss: 0.3039 - val_accuracy: 0.9099
# Epoch 104/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3777 - accuracy: 0.8844 - val_loss: 0.2014 - val_accuracy: 0.9097
# Epoch 105/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.4207 - accuracy: 0.8851 - val_loss: 0.1858 - val_accuracy: 0.9061
# Epoch 106/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6532 - accuracy: 0.8808 - val_loss: 0.5662 - val_accuracy: 0.7711
# Epoch 107/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3030 - accuracy: 0.8742 - val_loss: 0.3250 - val_accuracy: 0.8999
# Epoch 108/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8141 - accuracy: 0.8881 - val_loss: 0.1747 - val_accuracy: 0.9122
# Epoch 109/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4116 - accuracy: 0.8812 - val_loss: 0.2931 - val_accuracy: 0.8823
# Epoch 110/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8883 - accuracy: 0.8883 - val_loss: 0.4518 - val_accuracy: 0.8982
# Epoch 111/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.4363 - accuracy: 0.8942 - val_loss: 0.1590 - val_accuracy: 0.9116
# Epoch 112/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5655 - accuracy: 0.8941 - val_loss: 0.2004 - val_accuracy: 0.9145
# Epoch 113/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2699 - accuracy: 0.8824 - val_loss: 0.2775 - val_accuracy: 0.8947
# Epoch 114/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.1128 - accuracy: 0.8876 - val_loss: 0.7058 - val_accuracy: 0.7913
# Epoch 115/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0017 - accuracy: 0.8830 - val_loss: 0.2544 - val_accuracy: 0.9182
# Epoch 116/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9436 - accuracy: 0.8797 - val_loss: 0.3905 - val_accuracy: 0.8249
# Epoch 117/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1055 - accuracy: 0.8850 - val_loss: 0.4219 - val_accuracy: 0.8755
# Epoch 118/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.6755 - accuracy: 0.8870 - val_loss: 0.1945 - val_accuracy: 0.9112
# Epoch 119/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.5534 - accuracy: 0.8923 - val_loss: 0.2386 - val_accuracy: 0.8937
# Epoch 120/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6048 - accuracy: 0.8933 - val_loss: 1.0918 - val_accuracy: 0.7449
# Epoch 121/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7692 - accuracy: 0.8848 - val_loss: 0.7226 - val_accuracy: 0.8513
# Epoch 122/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1158 - accuracy: 0.8875 - val_loss: 0.2473 - val_accuracy: 0.9022
# Epoch 123/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.1461 - accuracy: 0.8609 - val_loss: 0.2549 - val_accuracy: 0.8851
# Epoch 124/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8485 - accuracy: 0.8889 - val_loss: 0.4154 - val_accuracy: 0.9024
# Epoch 125/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.1998 - accuracy: 0.9033 - val_loss: 0.1877 - val_accuracy: 0.9190
# Epoch 126/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.9494 - accuracy: 0.8942 - val_loss: 0.3534 - val_accuracy: 0.9032
# Epoch 127/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2166 - accuracy: 0.8901 - val_loss: 0.2703 - val_accuracy: 0.9097
# Epoch 128/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2246 - accuracy: 0.8885 - val_loss: 0.1910 - val_accuracy: 0.9127
# Epoch 129/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.7866 - accuracy: 0.8912 - val_loss: 0.3598 - val_accuracy: 0.8487
# Epoch 130/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6498 - accuracy: 0.9079 - val_loss: 0.1324 - val_accuracy: 0.9374
# Epoch 131/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5629 - accuracy: 0.9112 - val_loss: 0.1483 - val_accuracy: 0.9097
# Epoch 132/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4119 - accuracy: 0.8934 - val_loss: 0.1939 - val_accuracy: 0.9236
# Epoch 133/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.5147 - accuracy: 0.8907 - val_loss: 0.7116 - val_accuracy: 0.8816
# Epoch 134/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2427 - accuracy: 0.8924 - val_loss: 0.2091 - val_accuracy: 0.8753
# Epoch 135/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5970 - accuracy: 0.8980 - val_loss: 0.1659 - val_accuracy: 0.9110
# Epoch 136/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7889 - accuracy: 0.9031 - val_loss: 0.1901 - val_accuracy: 0.9016
# Epoch 137/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9933 - accuracy: 0.8919 - val_loss: 0.2427 - val_accuracy: 0.8868
# Epoch 138/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8483 - accuracy: 0.8969 - val_loss: 0.2026 - val_accuracy: 0.9040
# Epoch 139/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5445 - accuracy: 0.8973 - val_loss: 0.2348 - val_accuracy: 0.8722
# Epoch 140/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.9288 - accuracy: 0.8862 - val_loss: 0.1689 - val_accuracy: 0.9253
# Epoch 141/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8048 - accuracy: 0.8901 - val_loss: 0.1786 - val_accuracy: 0.9097
# Epoch 142/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6066 - accuracy: 0.8951 - val_loss: 0.1866 - val_accuracy: 0.9051
# Epoch 143/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7625 - accuracy: 0.8839 - val_loss: 0.1748 - val_accuracy: 0.9239
# Epoch 144/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9962 - accuracy: 0.8981 - val_loss: 0.1644 - val_accuracy: 0.8872
# Epoch 145/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1446 - accuracy: 0.8824 - val_loss: 0.1892 - val_accuracy: 0.9145
# Epoch 146/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7734 - accuracy: 0.8916 - val_loss: 0.4796 - val_accuracy: 0.8617
# Epoch 147/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2563 - accuracy: 0.8802 - val_loss: 0.2569 - val_accuracy: 0.9213
# Epoch 148/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.5298 - accuracy: 0.9006 - val_loss: 0.1786 - val_accuracy: 0.8460
# Epoch 149/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3544 - accuracy: 0.9030 - val_loss: 0.1776 - val_accuracy: 0.9207
# Epoch 150/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5072 - accuracy: 0.9061 - val_loss: 0.2756 - val_accuracy: 0.8967
# Epoch 151/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6973 - accuracy: 0.8954 - val_loss: 0.2544 - val_accuracy: 0.8999
# Epoch 152/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7732 - accuracy: 0.8994 - val_loss: 0.2025 - val_accuracy: 0.9256
# Epoch 153/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6224 - accuracy: 0.8807 - val_loss: 0.5365 - val_accuracy: 0.8526
# Epoch 154/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7953 - accuracy: 0.8941 - val_loss: 0.3551 - val_accuracy: 0.8529
# Epoch 155/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.0503 - accuracy: 0.8983 - val_loss: 1.8383 - val_accuracy: 0.6646
# Epoch 156/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.4425 - accuracy: 0.8863 - val_loss: 0.1872 - val_accuracy: 0.9155
# Epoch 157/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5035 - accuracy: 0.9018 - val_loss: 0.2106 - val_accuracy: 0.8973
# Epoch 158/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6746 - accuracy: 0.9016 - val_loss: 0.3657 - val_accuracy: 0.8946
# Epoch 159/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 32.1720 - accuracy: 0.8616 - val_loss: 0.2371 - val_accuracy: 0.8967
# Epoch 160/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8668 - accuracy: 0.8955 - val_loss: 0.1432 - val_accuracy: 0.9126
# Epoch 161/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7796 - accuracy: 0.9164 - val_loss: 0.5340 - val_accuracy: 0.8559
# Epoch 162/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.3968 - accuracy: 0.9091 - val_loss: 0.3768 - val_accuracy: 0.8764
# Epoch 163/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.2834 - accuracy: 0.8995 - val_loss: 0.2382 - val_accuracy: 0.9164
# Epoch 164/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6550 - accuracy: 0.9000 - val_loss: 0.1738 - val_accuracy: 0.9139
# Epoch 165/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0855 - accuracy: 0.8966 - val_loss: 0.2048 - val_accuracy: 0.8931
# Epoch 166/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5636 - accuracy: 0.8942 - val_loss: 0.2011 - val_accuracy: 0.9139
# Epoch 167/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7704 - accuracy: 0.9026 - val_loss: 0.5136 - val_accuracy: 0.8601
# Epoch 168/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.2005 - accuracy: 0.8986 - val_loss: 0.2035 - val_accuracy: 0.8830
# Epoch 169/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6878 - accuracy: 0.8982 - val_loss: 0.1493 - val_accuracy: 0.9276
# Epoch 170/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9205 - accuracy: 0.8998 - val_loss: 0.1407 - val_accuracy: 0.9357
# Epoch 171/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.9412 - accuracy: 0.9035 - val_loss: 0.2969 - val_accuracy: 0.8503
# Epoch 172/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8327 - accuracy: 0.8929 - val_loss: 0.1709 - val_accuracy: 0.9054
# Epoch 173/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0018 - accuracy: 0.8950 - val_loss: 0.1499 - val_accuracy: 0.9257
# Epoch 174/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2479 - accuracy: 0.9170 - val_loss: 0.1624 - val_accuracy: 0.9380
# Epoch 175/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0617 - accuracy: 0.9055 - val_loss: 0.2037 - val_accuracy: 0.8966
# Epoch 176/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8461 - accuracy: 0.9047 - val_loss: 0.1514 - val_accuracy: 0.9119
# Epoch 177/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6465 - accuracy: 0.9003 - val_loss: 0.2780 - val_accuracy: 0.8881
# Epoch 178/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8482 - accuracy: 0.8910 - val_loss: 0.2349 - val_accuracy: 0.9230
# Epoch 179/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9301 - accuracy: 0.8860 - val_loss: 0.1941 - val_accuracy: 0.8941
# Epoch 180/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7413 - accuracy: 0.8948 - val_loss: 0.1322 - val_accuracy: 0.9283
# Epoch 181/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7532 - accuracy: 0.8980 - val_loss: 0.2262 - val_accuracy: 0.9198
# Epoch 182/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0713 - accuracy: 0.8867 - val_loss: 0.4101 - val_accuracy: 0.9027
# Epoch 183/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0496 - accuracy: 0.8819 - val_loss: 0.3440 - val_accuracy: 0.8320
# Epoch 184/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8225 - accuracy: 0.8937 - val_loss: 0.5590 - val_accuracy: 0.7886
# Epoch 185/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7786 - accuracy: 0.8933 - val_loss: 0.1949 - val_accuracy: 0.8666
# Epoch 186/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.6210 - accuracy: 0.8877 - val_loss: 0.2358 - val_accuracy: 0.8784
# Epoch 187/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6722 - accuracy: 0.9040 - val_loss: 0.2644 - val_accuracy: 0.9221
# Epoch 188/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8029 - accuracy: 0.9035 - val_loss: 0.2367 - val_accuracy: 0.8992
# Epoch 189/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.7664 - accuracy: 0.8945 - val_loss: 0.3039 - val_accuracy: 0.8846
# Epoch 190/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5780 - accuracy: 0.9039 - val_loss: 0.3102 - val_accuracy: 0.8301
# Epoch 191/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9472 - accuracy: 0.9100 - val_loss: 0.1649 - val_accuracy: 0.9156
# Epoch 192/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4717 - accuracy: 0.9002 - val_loss: 0.1978 - val_accuracy: 0.8888
# Epoch 193/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.6197 - accuracy: 0.9052 - val_loss: 0.1167 - val_accuracy: 0.9169
# Epoch 194/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0536 - accuracy: 0.9054 - val_loss: 0.1630 - val_accuracy: 0.9247
# Epoch 195/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.1237 - accuracy: 0.9108 - val_loss: 0.3476 - val_accuracy: 0.8705
# Epoch 196/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6580 - accuracy: 0.9209 - val_loss: 0.1298 - val_accuracy: 0.9263
# Epoch 197/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5633 - accuracy: 0.9150 - val_loss: 0.2486 - val_accuracy: 0.8699
# Epoch 198/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5438 - accuracy: 0.9072 - val_loss: 0.1233 - val_accuracy: 0.9331
# Epoch 199/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8560 - accuracy: 0.9025 - val_loss: 0.9114 - val_accuracy: 0.8487
# Epoch 200/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8273 - accuracy: 0.8845 - val_loss: 0.3686 - val_accuracy: 0.8990

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
def flatten(X):
    flattened_X = np.empty((X.shape[0], X.shape[2]))  # sample x features array.
    for i in range(X.shape[0]):
        flattened_X[i] = X[i, (X.shape[1]-1), :]
    return(flattened_X)

# %%
X_test.shape
# Out:
# (14852, 22)

# %%
valid_x_predictions = model.predict([X_test, y_test])
#mse = np.mean(np.power(flatten(test_X_selected) - flatten(valid_x_predictions), 2), axis=1)

mse = np.mean(np.power(X_test - valid_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test.tolist()})
# Out:
# 465/465 [==============================] - 1s 2ms/step

# %%
error_df
# Out:
#         reconstruction_error  true_class
# 38166               0.005757           0
# 122124              0.002438           0
# 137236              0.001822           0
# 59637               0.005584           0
# 117914              1.394617           1
# ...                      ...         ...
# 30563               1.973931           1
# 148505              0.000998           0
# 125705              1.498005           1
# 132943              0.000565           0
# 49983               2.240369           1
#
# [14852 rows x 2 columns]

# %%
error_df['true_class'].value_counts()
# Out:
# 0    7720
# 1    7132
# Name: true_class, dtype: int64

# %%
import matplotlib.pyplot as plt

# 데이터프레임 준비
true_class = error_df['true_class'].astype(str)
reconstruction_error = error_df['reconstruction_error']

# 박스 플롯 그리기
plt.figure(figsize=(8, 8))
plt.boxplot(
    [reconstruction_error[true_class == cls] for cls in sorted(true_class.unique())],
    labels=sorted(true_class.unique()),
    showfliers=False,
    vert=True,
    patch_artist=True
)

plt.ylabel('Distribution')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_8417/349485020.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
print(error_df)
# Out:
#         reconstruction_error  true_class
# 38166               0.005757           0
# 122124              0.002438           0
# 137236              0.001822           0
# 59637               0.005584           0
# 117914              1.394617           1
# ...                      ...         ...
# 30563               1.973931           1
# 148505              0.000998           0
# 125705              1.498005           1
# 132943              0.000565           0
# 49983               2.240369           1
#
# [14852 rows x 2 columns]

# %%
print(error_df[(error_df['reconstruction_error'] >= 3) & (error_df['true_class'] == 0)].count())
# Out:
# reconstruction_error    12
# true_class              12
# dtype: int64

# %%
print(error_df[(error_df['reconstruction_error'] < 3) & (error_df['true_class'] == 1)].count())
# Out:
# reconstruction_error    6377
# true_class              6377
# dtype: int64

# %%
# 그래프 보고 threshold 결정
threshold = 0.4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes with a specified y-axis limit
plt.figure(figsize=(8, 6))

# Add jitter to avoid overlapping points in the scatter plot
x_0 = np.random.normal(1, 0.04, size=len(true_class_0))  # Jitter for class 0
x_1 = np.random.normal(2, 0.04, size=len(true_class_1))  # Jitter for class 1

# Create the scatter plot
plt.scatter(x_0, true_class_0, color='orange', alpha=0.6, edgecolor='black', label='Class 0')
plt.scatter(x_1, true_class_1, color='blue', alpha=0.6, edgecolor='black', label='Class 1')

# Set y-axis limit
plt.ylim(0, 4)

# Set x-axis labels and adjust ticks
plt.xticks([1, 2], ['0', '1'])
plt.xlabel('True Class')

# Set y-axis label and title
plt.ylabel('Reconstruction Error')
plt.title('Reconstruction Error by True Class')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 8))

# Create a swarm plot equivalent using scatter plot with more jitter
x_0 = np.random.normal(1, 0.1, size=len(true_class_0))  # Increased jitter for class 0
x_1 = np.random.normal(2, 0.1, size=len(true_class_1))  # Increased jitter for class 1

ax.scatter(x_0, true_class_0, color='blue', alpha=0.6, label='Class 0', edgecolor='w', s=50)
ax.scatter(x_1, true_class_1, color='orange', alpha=0.6, label='Class 1', edgecolor='w', s=50)

# Create boxplots
ax.boxplot([true_class_0, true_class_1], positions=[1, 2], widths=0.6, patch_artist=True, 
           showfliers=False, boxprops=dict(facecolor='None', color='black'),
           medianprops=dict(color='black'), whiskerprops=dict(color='black'))

# Set x-axis labels
ax.set_xticks([1, 2])
ax.set_xticklabels(['Class 0', 'Class 1'])

# Add a horizontal line at the threshold
ax.axhline(y=0.03, xmin=0.0, xmax=1, dashes=(5, 5), color='red')

# Adjust y-axis limit to make sure the threshold line is visible
#ax.set_ylim(bottom=min(min(true_class_0), min(true_class_1)) - 0.01, 
#           top=max(max(true_class_0), max(true_class_1)) + 0.01)
ax.set_ylim(bottom=0, top=10)
    
# Set labels and title
ax.set_ylabel('Reconstruction Error')
ax.set_title('Reconstruction Error by Class')

plt.show()

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='^', ms=3.5, linestyle='',
            label= "Normal" if name == 0 else "Fall")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.set_ylim(0, 4)
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
import numpy as np
from sklearn.metrics import f1_score

# Define the range of threshold values
threshold_range = np.arange(0.0001, 10, 0.001)

# List to store F1 scores for each threshold
f1_scores = []

# Loop through each threshold and calculate F1 score
for threshold in threshold_range:
    y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
    f1 = f1_score(error_df.true_class, y_pred)
    f1_scores.append(f1)

# Find the threshold with the highest F1 score
best_threshold = threshold_range[np.argmax(f1_scores)]
best_f1_score = max(f1_scores)

print(f"Best threshold: {best_threshold}")
print(f"Best F1 score: {best_f1_score}")

# Optionally, you can plot the F1 scores across the threshold range
plt.plot(threshold_range, f1_scores, marker='o')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Threshold')
plt.show()
# Out:
# Best threshold: 0.3271
# Best F1 score: 0.997272154997552

# %%
# 그래프 보고 threshold 결정
threshold = 0.3271

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Assuming you have already defined LABELS, threshold, and y_pred

LABELS = ["Attack", "Normal"]

y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

# Create the figure and axis
plt.figure(figsize=(12, 12))
fig, ax = plt.subplots()

# Plot the confusion matrix using imshow
cax = ax.matshow(conf_matrix, cmap=plt.cm.Blues)

# Add color bar
plt.colorbar(cax)

# Set the labels for the axes
ax.set_xticks(np.arange(len(LABELS)))
ax.set_yticks(np.arange(len(LABELS)))

ax.set_xticklabels(LABELS)
ax.set_yticklabels(LABELS)

# Set labels and title
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.title('Confusion matrix')

# Annotate the confusion matrix with the counts
for i in range(len(LABELS)):
    for j in range(len(LABELS)):
        ax.text(j, i, format(conf_matrix[i, j], 'd'),
                ha="center", va="center",
                color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

precision, recall, f1,_ = precision_recall_fscore_support(y_test,y_pred,average='binary')
print ('Accuracy Score :',accuracy_score(error_df.true_class, y_pred) )
print ('Precision :',precision )
print ('Recall :',recall )
print ('F1 :',f1 )
# Out:
# Accuracy Score : 0.9973740910315109
# Precision : 0.9949755757152826
# Recall : 0.9995793606281548
# F1 : 0.997272154997552

# %%
from sklearn.metrics import roc_curve, auc

# Assuming y_test and reconstruction_error have been defined
fpr, tpr, thresholds = roc_curve(y_test, reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Extract the true labels and reconstruction errors from error_df
y_true = error_df['true_class']
y_scores = error_df['reconstruction_error']

# Compute the False Positive Rate (FPR) and True Positive Rate (TPR) for different thresholds
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')

# Set plot labels and title
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")

# Display the plot
plt.show()

# %%
print(f"ROC Score : {roc_auc}")
# Out:
# ROC Score : 0.9982304631537346

# %%
# If error_df.true_class is a nested structure, flatten it
y_test = error_df.true_class.apply(lambda x: int(x[0][0]) if isinstance(x, list) else int(x))

# Ensure y_pred is a list of integers
y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]

# Now calculate the metrics
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Accuracy Score:', accuracy_score(y_test, y_pred))
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy Score: 0.9973740910315109
# Precision: 0.9949755757152826
# Recall: 0.9995793606281548
# F1 Score: 0.997272154997552
