# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# Out:
# 2024-12-27 03:22:44.578537: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-27 03:22:44.578604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-27 03:22:44.578642: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-27 03:22:44.587557: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !pip install --upgrade matplotlib seaborn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/work/.local/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /home/work/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.3.post1)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.losses import mse, binary_crossentropy, kl_divergence
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import scale


import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('../newKDDTrain+.txt', header=None)

columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
train_df.columns = columns

train_df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate    class
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  anomaly
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
test_df = pd.read_csv('../newKDDTest+.txt', header=None)

test_columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
test_df.columns = columns

test_df.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  86
# 3               0       0    0  ...                  57
# 4               0       0    0  ...                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate    class
# 0                      1.00  anomaly
# 1                      1.00  anomaly
# 2                      0.00   normal
# 3                      0.00  anomaly
# 4                      0.71  anomaly
#
# [5 rows x 42 columns]

# %%
df = pd.concat([train_df, test_df])

# %%
df['class']
# Out:
# 0         normal
# 1         normal
# 2        anomaly
# 3         normal
# 4         normal
#           ...
# 22539     normal
# 22540     normal
# 22541    anomaly
# 22542     normal
# 22543    anomaly
# Name: class, Length: 148517, dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
len(df.columns)
# Out:
# 42

# %%
df.shape
# Out:
# (148517, 42)

# %%
# 'label' 열의 값이 'normal.'이면 0으로, 'normal.'이 아니면 1로 변경
df['class'] = df['class'].apply(lambda x: 0 if x == 'normal' else 1)

# 변경된 데이터프레임 확인
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding 적용
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['service'] = label_encoder.fit_transform(df['service'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# 인코딩된 데이터프레임 확인
print(df.head())
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       20     9        491          0     0
# 1         0              2       44     9        146          0     0
# 2         0              1       49     5          0          0     0
# 3         0              1       24     9        232       8153     0
# 4         0              1       24     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (148517, 42)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

tmp = df.drop(labels = 'class',axis=1)
labels = df['class']

# 1. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(tmp)

# 2. PCA 적용 (주성분 개수 설정)
n_components = 16  # 원하는 차원 수로 설정
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)


# 3. PCA 누적 분산 비율 확인
explained_variance_ratio = pca.explained_variance_ratio_.cumsum()
print("누적 분산 비율 (cumulative explained variance):")
print(explained_variance_ratio)

# 4. PCA 결과를 DataFrame으로 변환하고 label 병합
X_pca_df = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(n_components)])
df_merged = X_pca_df.assign(label=labels.values)

# 열 이름 변경 (label -> class)
df_merged.rename(columns={'label': 'class'}, inplace=True)


# 5. 병합된 데이터 타입 확인
print("Label 데이터 타입:", df_merged['class'].dtype)

# 6. 정렬 여부 확인 (필요하면 추가)
# 확인 예시: 병합 전후 `labels` 순서와 `df_merged['label']`이 동일한지 점검
assert np.array_equal(labels.values, df_merged['class'].values), "Label 순서가 일치하지 않습니다."

# 7. PCA 결과 시각화 (2D로 줄인 경우)
import matplotlib.pyplot as plt
if n_components >= 2:
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.5)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title('PCA 결과 시각화')
    plt.colorbar(label='Label')
    plt.show()
# Out:
# 누적 분산 비율 (cumulative explained variance):
# [0.18919362 0.317851   0.38738707 0.43961021 0.48649999 0.5288269
#  0.56767527 0.60102595 0.6293433  0.6560306  0.68175228 0.7073138
#  0.73231309 0.75726198 0.7820965  0.80684369]
# Label 데이터 타입: int64
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#엘보우 방법
import matplotlib.pyplot as plt

# 각 주성분의 분산 비율
explained_variance_ratio = pca.explained_variance_ratio_

# 시각화
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
# 누적 분산 비율 계산
cumulative_variance_ratio = pca.explained_variance_ratio_.cumsum()

# 누적 분산 비율 출력
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance Ratio')
plt.grid()
plt.show()

# %%
# X_pca를 DataFrame으로 변환
X_pca_df = pd.DataFrame(X_pca)

# `assign`으로 label 추가
df_merged = X_pca_df.assign(label=df['class'].values)

# %%
df = df_merged

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.937418 -0.099287 -0.033566  0.114384 -0.111566  0.447066 -0.369544
# 1  0.685952  0.530798  0.084383 -0.313909  0.078466  2.453972 -3.184688
# 2  3.557238 -2.531658  0.044014  0.309695 -0.259172 -0.446912 -0.130178
# 3 -2.613555 -0.501687 -0.070463  0.034837 -0.304217 -1.014990  0.093413
# 4 -2.403516 -0.363546 -0.127572 -1.076378  0.105770 -0.663262  0.163167
#
#           7         8         9        10        11        12        13  \
# 0  0.122389  0.166336  0.210956 -0.014398  0.041596  0.007462 -0.003309
# 1  0.748822 -0.690477 -0.284627  0.057519 -0.047756 -0.050353  0.164400
# 2  0.014002  0.166750  0.091960  0.024872  0.012914  0.020617 -0.057251
# 3  0.047611  0.012705 -0.235274 -0.017438  0.032976 -0.000511  0.056756
# 4 -0.015095 -0.020067 -0.344713  0.078408 -0.002132 -0.000173  0.033806
#
#          14        15  label
# 0 -0.111580  0.111881      0
# 1  0.152604 -0.075569      0
# 2 -0.047055  0.020875      1
# 3  0.043072  0.049593      0
# 4  0.104476 -0.094610      0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df, test_size=0.1, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((133665, 17), (14852, 17))

# %%
X_train_normal = X_train[X_train['label'] == 0]
X_train_normal.shape

X_test_normal = X_test[X_test['label'] == 0]
X_test_normal.shape
# Out:
# (7720, 17)

# %%
y_train_normal = X_train_normal['label']
X_train_normal = X_train_normal.drop(labels='label',axis=1)

y_test_normal = X_test_normal['label']
X_test_normal = X_test_normal.drop(labels='label',axis=1)

# %%
y_test = X_test['label']
X_test = X_test.drop(labels='label', axis=1)

# %%
# !pip install keras_self_attention
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_self_attention in /home/work/.local/lib/python3.10/site-packages (0.51.0)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (from keras_self_attention) (1.26.4)

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector, Conv1D, Conv1DTranspose
from keras.models import Model
from keras import regularizers
from keras_self_attention import SeqWeightedAttention, SeqSelfAttention
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
from tensorflow.keras import layers, losses, Model, Input
import numpy as np
from tensorflow.keras import backend as K

latent_dim = 10
inter_dim = 20

# Sampling function for reparameterization trick
def sampling(args):
    z_mean, z_log_sigma = args
    batch_size = tf.shape(z_mean)[0]
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=1.)
    return z_mean + z_log_sigma * epsilon

def vae_loss(x, x_decoded_mean, z_mean, z_log_sigma):
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean), axis=1)
    kl_loss = -0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma), axis=-1)
    kl_loss_weighted = kl_loss * 0.001  # KL 다이버전스 손실에 가중치 부여
    total_loss = K.mean(reconstruction_loss + kl_loss_weighted)
    return total_loss

def cvae(X, labels):
    features = X.shape[1]  # 2D 데이터이므로 timesteps는 필요 없고, features만 사용
    input_x = Input(shape=(features,), name='InputFeatures')  # 2D 입력 (샘플, 특징)

    input_label = Input(shape=(1,), name='InputLabel')  # Assumes binary or multi-class label

    # Embed the label into the same shape as the input
    embedded_label = layers.Embedding(input_dim=2, output_dim=features)(input_label)  # Adjust output_dim to match features
    embedded_label = layers.Flatten()(embedded_label)

    # Concatenate input_x and embedded_label
    concatenated_input = layers.Concatenate()([input_x, embedded_label])

    # Reshape for Conv1D layer (to 3D)
    reshaped_input = layers.Reshape((features + embedded_label.shape[-1], 1))(concatenated_input)

    # Encoder with CNN layers
    h = layers.Conv1D(filters=64, kernel_size=3, activation="relu", padding='same')(reshaped_input)
    h = layers.Conv1D(filters=32, kernel_size=3, activation="relu", padding='same')(h)
    h = layers.Conv1D(filters=16, kernel_size=3, activation="relu", padding='same')(h)

    # Flatten for dense layers (MLP)
    h = layers.Flatten()(h)
    h = layers.Dense(inter_dim, activation='relu')(h)
    h = layers.Dense(inter_dim, activation='relu')(h)

    # z layer
    z_mean = layers.Dense(latent_dim)(h)
    z_log_sigma = layers.Dense(latent_dim)(h)
    z = layers.Lambda(sampling)([z_mean, z_log_sigma])

    # Decoder
    # Add the label to the latent space z
    z_with_label = layers.Concatenate()([z, embedded_label])

    # Expand for Conv1DTranspose layer
    decoder1 = layers.Dense((features + embedded_label.shape[-1]) * inter_dim)(z_with_label)
    decoder1 = layers.Reshape((features + embedded_label.shape[-1], inter_dim))(decoder1)

    # Decoder with CNN layers
    decoder1 = layers.Conv1DTranspose(filters=16, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=32, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=64, kernel_size=3, activation="relu", padding='same')(decoder1)

    # Flatten and final dense layer to reconstruct original features
    decoder1 = layers.Flatten()(decoder1)
    decoder1 = layers.Dense(features)(decoder1)
    
    model = Model([input_x, input_label], decoder1)
    model.add_loss(vae_loss(input_x, decoder1, z_mean, z_log_sigma))
    
    return model

# Create CVAE model
model = cvae(X_train_normal, y_train_normal)
model.summary()

# Compile and train the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy'])
history = model.fit([X_train_normal, y_train_normal], X_train_normal,
                    shuffle=True,
                    epochs=200, 
                    validation_split=0.1,  
                    batch_size=32).history
# Out:
# 2024-12-27 03:23:01.333691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:c8:00.0, compute capability: 8.0
# 2024-12-27 03:23:01.336048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38698 MB memory:  -> device: 1, name: CUDA GPU, pci bus id: 0000:cc:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  InputLabel (InputLayer)     [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 16)                32        ['InputLabel[0][0]']
#
#  InputFeatures (InputLayer)  [(None, 16)]                 0         []
#
#  flatten (Flatten)           (None, 16)                   0         ['embedding[0][0]']
#
#  concatenate (Concatenate)   (None, 32)                   0         ['InputFeatures[0][0]',
#                                                                      'flatten[0][0]']
#
#  reshape (Reshape)           (None, 32, 1)                0         ['concatenate[0][0]']
#
#  conv1d (Conv1D)             (None, 32, 64)               256       ['reshape[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 32, 32)               6176      ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 32, 16)               1552      ['conv1d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 512)                  0         ['conv1d_2[0][0]']
#
#  dense (Dense)               (None, 20)                   10260     ['flatten_1[0][0]']
#
#  dense_1 (Dense)             (None, 20)                   420       ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 10)                   0         ['dense_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 26)                   0         ['lambda[0][0]',
#  )                                                                   'flatten[0][0]']
#
#  dense_4 (Dense)             (None, 640)                  17280     ['concatenate_1[0][0]']
#
#  reshape_1 (Reshape)         (None, 32, 20)               0         ['dense_4[0][0]']
#
#  conv1d_transpose (Conv1DTr  (None, 32, 16)               976       ['reshape_1[0][0]']
#  anspose)
#
#  conv1d_transpose_1 (Conv1D  (None, 32, 32)               1568      ['conv1d_transpose[0][0]']
#  Transpose)
#
#  conv1d_transpose_2 (Conv1D  (None, 32, 64)               6208      ['conv1d_transpose_1[0][0]']
#  Transpose)
#
#  flatten_2 (Flatten)         (None, 2048)                 0         ['conv1d_transpose_2[0][0]']
#
#  dense_5 (Dense)             (None, 16)                   32784     ['flatten_2[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['dense_3[0][0]']
#  Lambda)
#
#  tf.math.square_1 (TFOpLamb  (None, 10)                   0         ['dense_2[0][0]']
#  da)
#
#  tf.math.subtract_1 (TFOpLa  (None, 10)                   0         ['tf.__operators__.add[0][0]',
#  mbda)                                                               'tf.math.square_1[0][0]']
#
#  tf.math.exp (TFOpLambda)    (None, 10)                   0         ['dense_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 10)                   0         ['tf.math.subtract_1[0][0]',
#  mbda)                                                               'tf.math.exp[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 16)                   0         ['InputFeatures[0][0]',
#  da)                                                                 'dense_5[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None,)                      0         ['tf.math.subtract_2[0][0]']
#  Lambda)
#
#  tf.math.square (TFOpLambda  (None, 16)                   0         ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.math.reduce_sum_1[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLa  (None,)                      0         ['tf.math.square[0][0]']
#  mbda)
#
#  tf.math.multiply_1 (TFOpLa  (None,)                      0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.__operators__.add_1 (TF  (None,)                      0         ['tf.math.reduce_sum[0][0]',
#  OpLambda)                                                           'tf.math.multiply_1[0][0]']
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.__operators__.add_1[0][0]
#  ambda)                                                             ']
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 77932 (304.42 KB)
# Trainable params: 77932 (304.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 2024-12-27 03:23:03.527746: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-12-27 03:23:04.119384: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f45f105dae0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-27 03:23:04.119438: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2024-12-27 03:23:04.119444: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): CUDA GPU, Compute Capability 8.0
# 2024-12-27 03:23:04.124089: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-27 03:23:04.201425: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1950/1950 [==============================] - 15s 6ms/step - loss: 18.1707 - accuracy: 0.4978 - val_loss: 3.4955 - val_accuracy: 0.4119
# Epoch 2/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 12282553344.0000 - accuracy: 0.6263 - val_loss: 0.9302 - val_accuracy: 0.7238
# Epoch 3/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 4.8751 - accuracy: 0.6750 - val_loss: 0.6845 - val_accuracy: 0.7235
# Epoch 4/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.3633 - accuracy: 0.7063 - val_loss: 0.6116 - val_accuracy: 0.6827
# Epoch 5/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3863 - accuracy: 0.6825 - val_loss: 0.4182 - val_accuracy: 0.7600
# Epoch 6/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3443 - accuracy: 0.7123 - val_loss: 0.5543 - val_accuracy: 0.7106
# Epoch 7/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.1447 - accuracy: 0.7475 - val_loss: 0.3705 - val_accuracy: 0.8333
# Epoch 8/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2662 - accuracy: 0.7629 - val_loss: 4.6145 - val_accuracy: 0.4815
# Epoch 9/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 16.0732 - accuracy: 0.7578 - val_loss: 0.3536 - val_accuracy: 0.8142
# Epoch 10/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3999 - accuracy: 0.8003 - val_loss: 0.2441 - val_accuracy: 0.8630
# Epoch 11/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.1590 - accuracy: 0.7843 - val_loss: 0.3855 - val_accuracy: 0.6635
# Epoch 12/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.6902 - accuracy: 0.8086 - val_loss: 0.3905 - val_accuracy: 0.7463
# Epoch 13/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3596 - accuracy: 0.7750 - val_loss: 0.7877 - val_accuracy: 0.7547
# Epoch 14/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.4631 - accuracy: 0.7481 - val_loss: 0.3108 - val_accuracy: 0.8401
# Epoch 15/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 15.2956 - accuracy: 0.7788 - val_loss: 0.2635 - val_accuracy: 0.8043
# Epoch 16/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7099 - accuracy: 0.8013 - val_loss: 0.1852 - val_accuracy: 0.8729
# Epoch 17/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0568 - accuracy: 0.7820 - val_loss: 0.2057 - val_accuracy: 0.8532
# Epoch 18/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.8207 - accuracy: 0.8196 - val_loss: 0.2295 - val_accuracy: 0.8724
# Epoch 19/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.7169 - accuracy: 0.8248 - val_loss: 0.2136 - val_accuracy: 0.7769
# Epoch 20/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6301 - accuracy: 0.7981 - val_loss: 0.5100 - val_accuracy: 0.7416
# Epoch 21/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7498 - accuracy: 0.7790 - val_loss: 0.2107 - val_accuracy: 0.8267
# Epoch 22/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6216 - accuracy: 0.7752 - val_loss: 0.1696 - val_accuracy: 0.7881
# Epoch 23/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7344 - accuracy: 0.8127 - val_loss: 0.1820 - val_accuracy: 0.8435
# Epoch 24/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8944 - accuracy: 0.7857 - val_loss: 0.1547 - val_accuracy: 0.8670
# Epoch 25/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9012 - accuracy: 0.7992 - val_loss: 0.3658 - val_accuracy: 0.8437
# Epoch 26/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.2988 - accuracy: 0.7735 - val_loss: 0.2168 - val_accuracy: 0.8369
# Epoch 27/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.6109 - accuracy: 0.8079 - val_loss: 0.9208 - val_accuracy: 0.7597
# Epoch 28/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2380 - accuracy: 0.7609 - val_loss: 0.6380 - val_accuracy: 0.7472
# Epoch 29/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 40.1753 - accuracy: 0.7532 - val_loss: 0.5041 - val_accuracy: 0.7194
# Epoch 30/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8712 - accuracy: 0.7621 - val_loss: 0.2151 - val_accuracy: 0.8207
# Epoch 31/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.8907 - accuracy: 0.8024 - val_loss: 0.3478 - val_accuracy: 0.8279
# Epoch 32/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2337 - accuracy: 0.8051 - val_loss: 0.2168 - val_accuracy: 0.8719
# Epoch 33/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.3621 - accuracy: 0.8264 - val_loss: 0.2186 - val_accuracy: 0.8204
# Epoch 34/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.8206 - accuracy: 0.8008 - val_loss: 0.2054 - val_accuracy: 0.7889
# Epoch 35/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0189 - accuracy: 0.7906 - val_loss: 0.3313 - val_accuracy: 0.6572
# Epoch 36/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6254 - accuracy: 0.7855 - val_loss: 0.2765 - val_accuracy: 0.8391
# Epoch 37/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0633 - accuracy: 0.7953 - val_loss: 0.1567 - val_accuracy: 0.8359
# Epoch 38/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9129 - accuracy: 0.7705 - val_loss: 0.2687 - val_accuracy: 0.7744
# Epoch 39/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8459 - accuracy: 0.7418 - val_loss: 0.2706 - val_accuracy: 0.7857
# Epoch 40/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3532 - accuracy: 0.7896 - val_loss: 0.3345 - val_accuracy: 0.7961
# Epoch 41/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4960 - accuracy: 0.7985 - val_loss: 0.5658 - val_accuracy: 0.8078
# Epoch 42/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 391.4528 - accuracy: 0.7797 - val_loss: 0.4727 - val_accuracy: 0.6627
# Epoch 43/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.9357 - accuracy: 0.7543 - val_loss: 0.3416 - val_accuracy: 0.8367
# Epoch 44/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8878 - accuracy: 0.8206 - val_loss: 0.4080 - val_accuracy: 0.8145
# Epoch 45/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0475 - accuracy: 0.8166 - val_loss: 0.2046 - val_accuracy: 0.8862
# Epoch 46/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6221 - accuracy: 0.8432 - val_loss: 0.1369 - val_accuracy: 0.8895
# Epoch 47/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4320 - accuracy: 0.8121 - val_loss: 0.2783 - val_accuracy: 0.7527
# Epoch 48/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3020 - accuracy: 0.7917 - val_loss: 0.2141 - val_accuracy: 0.7918
# Epoch 49/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8869 - accuracy: 0.8465 - val_loss: 1.0617 - val_accuracy: 0.5878
# Epoch 50/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7714 - accuracy: 0.8219 - val_loss: 0.1685 - val_accuracy: 0.8365
# Epoch 51/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4210 - accuracy: 0.8222 - val_loss: 0.3032 - val_accuracy: 0.8468
# Epoch 52/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3711 - accuracy: 0.7896 - val_loss: 0.2618 - val_accuracy: 0.6207
# Epoch 53/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5011 - accuracy: 0.7728 - val_loss: 0.3020 - val_accuracy: 0.8405
# Epoch 54/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8455 - accuracy: 0.8032 - val_loss: 0.2294 - val_accuracy: 0.8455
# Epoch 55/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5525 - accuracy: 0.7964 - val_loss: 0.2067 - val_accuracy: 0.7711
# Epoch 56/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.6271 - accuracy: 0.7848 - val_loss: 0.2089 - val_accuracy: 0.7788
# Epoch 57/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8226 - accuracy: 0.8157 - val_loss: 0.6819 - val_accuracy: 0.4262
# Epoch 58/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1733 - accuracy: 0.8036 - val_loss: 0.3108 - val_accuracy: 0.7698
# Epoch 59/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3237 - accuracy: 0.7959 - val_loss: 0.3246 - val_accuracy: 0.8228
# Epoch 60/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.8507 - accuracy: 0.8115 - val_loss: 0.6441 - val_accuracy: 0.6989
# Epoch 61/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3753 - accuracy: 0.7709 - val_loss: 0.4608 - val_accuracy: 0.8187
# Epoch 62/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7565 - accuracy: 0.8396 - val_loss: 1.5327 - val_accuracy: 0.5280
# Epoch 63/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2546 - accuracy: 0.7941 - val_loss: 0.2029 - val_accuracy: 0.8581
# Epoch 64/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.3081 - accuracy: 0.8132 - val_loss: 0.3443 - val_accuracy: 0.7573
# Epoch 65/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 191.0506 - accuracy: 0.7914 - val_loss: 0.2559 - val_accuracy: 0.8496
# Epoch 66/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6725 - accuracy: 0.7891 - val_loss: 0.2438 - val_accuracy: 0.8304
# Epoch 67/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5052 - accuracy: 0.8170 - val_loss: 0.2227 - val_accuracy: 0.7755
# Epoch 68/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.7672 - accuracy: 0.8328 - val_loss: 0.6785 - val_accuracy: 0.6758
# Epoch 69/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4529 - accuracy: 0.8433 - val_loss: 0.1446 - val_accuracy: 0.8980
# Epoch 70/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5378 - accuracy: 0.8332 - val_loss: 0.1334 - val_accuracy: 0.8640
# Epoch 71/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.3318 - accuracy: 0.8332 - val_loss: 0.2411 - val_accuracy: 0.8483
# Epoch 72/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.5657 - accuracy: 0.7963 - val_loss: 0.1531 - val_accuracy: 0.8620
# Epoch 73/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3596 - accuracy: 0.8244 - val_loss: 0.1825 - val_accuracy: 0.8496
# Epoch 74/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3165 - accuracy: 0.8305 - val_loss: 1.2217 - val_accuracy: 0.6253
# Epoch 75/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4216 - accuracy: 0.7731 - val_loss: 0.2438 - val_accuracy: 0.8849
# Epoch 76/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.9166 - accuracy: 0.7980 - val_loss: 0.1771 - val_accuracy: 0.8665
# Epoch 77/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6068 - accuracy: 0.8356 - val_loss: 0.1239 - val_accuracy: 0.8428
# Epoch 78/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.7641 - accuracy: 0.8280 - val_loss: 0.1229 - val_accuracy: 0.9047
# Epoch 79/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 130.1874 - accuracy: 0.8070 - val_loss: 0.1596 - val_accuracy: 0.8440
# Epoch 80/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.3043 - accuracy: 0.8636 - val_loss: 0.1317 - val_accuracy: 0.8995
# Epoch 81/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.3209 - accuracy: 0.8750 - val_loss: 0.1088 - val_accuracy: 0.9090
# Epoch 82/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8241 - accuracy: 0.8659 - val_loss: 0.1289 - val_accuracy: 0.8817
# Epoch 83/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0618 - accuracy: 0.8548 - val_loss: 0.1184 - val_accuracy: 0.9057
# Epoch 84/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4147 - accuracy: 0.8523 - val_loss: 0.2921 - val_accuracy: 0.6338
# Epoch 85/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5785 - accuracy: 0.8481 - val_loss: 0.1141 - val_accuracy: 0.8838
# Epoch 86/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.6687 - accuracy: 0.8298 - val_loss: 0.4012 - val_accuracy: 0.5939
# Epoch 87/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.0526 - accuracy: 0.7909 - val_loss: 0.3349 - val_accuracy: 0.7207
# Epoch 88/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.1170 - accuracy: 0.8035 - val_loss: 0.1495 - val_accuracy: 0.8232
# Epoch 89/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7676 - accuracy: 0.8176 - val_loss: 0.2450 - val_accuracy: 0.8920
# Epoch 90/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6538 - accuracy: 0.8383 - val_loss: 0.1497 - val_accuracy: 0.8688
# Epoch 91/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 7.4049 - accuracy: 0.8334 - val_loss: 0.3218 - val_accuracy: 0.8370
# Epoch 92/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0392 - accuracy: 0.8677 - val_loss: 0.1221 - val_accuracy: 0.9166
# Epoch 93/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1084 - accuracy: 0.8433 - val_loss: 0.1588 - val_accuracy: 0.8727
# Epoch 94/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.6231 - accuracy: 0.8413 - val_loss: 0.2344 - val_accuracy: 0.7974
# Epoch 95/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2750 - accuracy: 0.8344 - val_loss: 0.6126 - val_accuracy: 0.7211
# Epoch 96/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5129 - accuracy: 0.8253 - val_loss: 0.1513 - val_accuracy: 0.8979
# Epoch 97/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7252 - accuracy: 0.8445 - val_loss: 0.2527 - val_accuracy: 0.8392
# Epoch 98/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9574 - accuracy: 0.8240 - val_loss: 0.1465 - val_accuracy: 0.8686
# Epoch 99/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.4820 - accuracy: 0.8125 - val_loss: 0.1948 - val_accuracy: 0.8559
# Epoch 100/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5789 - accuracy: 0.8498 - val_loss: 4.2638 - val_accuracy: 0.4937
# Epoch 101/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9112 - accuracy: 0.8033 - val_loss: 0.1417 - val_accuracy: 0.8641
# Epoch 102/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.9665 - accuracy: 0.8331 - val_loss: 0.1536 - val_accuracy: 0.8711
# Epoch 103/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6545 - accuracy: 0.8384 - val_loss: 0.2938 - val_accuracy: 0.7717
# Epoch 104/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0484 - accuracy: 0.8251 - val_loss: 4.6621 - val_accuracy: 0.5306
# Epoch 105/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0417 - accuracy: 0.8269 - val_loss: 0.6114 - val_accuracy: 0.8491
# Epoch 106/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0470 - accuracy: 0.8421 - val_loss: 0.2930 - val_accuracy: 0.6239
# Epoch 107/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8184 - accuracy: 0.8332 - val_loss: 0.2391 - val_accuracy: 0.8510
# Epoch 108/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3302 - accuracy: 0.8451 - val_loss: 0.2683 - val_accuracy: 0.8503
# Epoch 109/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.4896 - accuracy: 0.8470 - val_loss: 0.1667 - val_accuracy: 0.8944
# Epoch 110/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.1073 - accuracy: 0.8231 - val_loss: 4.4099 - val_accuracy: 0.5138
# Epoch 111/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4203 - accuracy: 0.8205 - val_loss: 0.2157 - val_accuracy: 0.8591
# Epoch 112/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7395 - accuracy: 0.8431 - val_loss: 0.1291 - val_accuracy: 0.8882
# Epoch 113/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6908 - accuracy: 0.8359 - val_loss: 0.0985 - val_accuracy: 0.8989
# Epoch 114/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6726 - accuracy: 0.8110 - val_loss: 0.1416 - val_accuracy: 0.8350
# Epoch 115/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4223 - accuracy: 0.8055 - val_loss: 0.1508 - val_accuracy: 0.8688
# Epoch 116/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5164 - accuracy: 0.8254 - val_loss: 0.3643 - val_accuracy: 0.8810
# Epoch 117/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.8309 - accuracy: 0.8370 - val_loss: 0.1725 - val_accuracy: 0.8885
# Epoch 118/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.7699 - accuracy: 0.8001 - val_loss: 0.1740 - val_accuracy: 0.8138
# Epoch 119/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5127 - accuracy: 0.8237 - val_loss: 0.1739 - val_accuracy: 0.8731
# Epoch 120/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8601 - accuracy: 0.8188 - val_loss: 0.7776 - val_accuracy: 0.6428
# Epoch 121/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1724 - accuracy: 0.7807 - val_loss: 0.2350 - val_accuracy: 0.8569
# Epoch 122/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 857.9436 - accuracy: 0.8074 - val_loss: 0.1964 - val_accuracy: 0.8864
# Epoch 123/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3869 - accuracy: 0.8583 - val_loss: 0.1709 - val_accuracy: 0.8817
# Epoch 124/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.4119 - accuracy: 0.8725 - val_loss: 0.4440 - val_accuracy: 0.5757
# Epoch 125/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.3821 - accuracy: 0.8431 - val_loss: 0.0904 - val_accuracy: 0.8764
# Epoch 126/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.2814 - accuracy: 0.8490 - val_loss: 0.1602 - val_accuracy: 0.8647
# Epoch 127/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5877 - accuracy: 0.8311 - val_loss: 0.1737 - val_accuracy: 0.8490
# Epoch 128/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3099 - accuracy: 0.8468 - val_loss: 0.1640 - val_accuracy: 0.8356
# Epoch 129/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0392 - accuracy: 0.8146 - val_loss: 0.1483 - val_accuracy: 0.7733
# Epoch 130/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3035 - accuracy: 0.8390 - val_loss: 1.0189 - val_accuracy: 0.6612
# Epoch 131/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3800 - accuracy: 0.8371 - val_loss: 0.1480 - val_accuracy: 0.8166
# Epoch 132/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.3514 - accuracy: 0.8215 - val_loss: 0.1056 - val_accuracy: 0.8855
# Epoch 133/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5475 - accuracy: 0.8017 - val_loss: 0.1417 - val_accuracy: 0.8551
# Epoch 134/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5830 - accuracy: 0.8178 - val_loss: 0.2269 - val_accuracy: 0.8960
# Epoch 135/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.9210 - accuracy: 0.8054 - val_loss: 0.2389 - val_accuracy: 0.7620
# Epoch 136/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3033 - accuracy: 0.8259 - val_loss: 0.1340 - val_accuracy: 0.8647
# Epoch 137/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4414 - accuracy: 0.8424 - val_loss: 5.2297 - val_accuracy: 0.7972
# Epoch 138/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.3577 - accuracy: 0.8144 - val_loss: 0.1171 - val_accuracy: 0.9024
# Epoch 139/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.0396 - accuracy: 0.8329 - val_loss: 0.1068 - val_accuracy: 0.8905
# Epoch 140/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4135 - accuracy: 0.8311 - val_loss: 0.1234 - val_accuracy: 0.8662
# Epoch 141/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6084 - accuracy: 0.8099 - val_loss: 0.1721 - val_accuracy: 0.7028
# Epoch 142/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.1207 - accuracy: 0.8421 - val_loss: 0.1322 - val_accuracy: 0.8950
# Epoch 143/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8411 - accuracy: 0.8284 - val_loss: 0.1627 - val_accuracy: 0.8600
# Epoch 144/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4197 - accuracy: 0.8342 - val_loss: 0.1269 - val_accuracy: 0.9146
# Epoch 145/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2930 - accuracy: 0.8225 - val_loss: 0.1395 - val_accuracy: 0.8845
# Epoch 146/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4231 - accuracy: 0.8127 - val_loss: 0.3909 - val_accuracy: 0.7543
# Epoch 147/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4432 - accuracy: 0.8202 - val_loss: 0.3964 - val_accuracy: 0.6331
# Epoch 148/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6136 - accuracy: 0.8189 - val_loss: 0.1411 - val_accuracy: 0.8905
# Epoch 149/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.1769 - accuracy: 0.8139 - val_loss: 0.1809 - val_accuracy: 0.9115
# Epoch 150/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.4163 - accuracy: 0.8204 - val_loss: 0.1223 - val_accuracy: 0.8539
# Epoch 151/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8404 - accuracy: 0.8164 - val_loss: 0.1114 - val_accuracy: 0.8833
# Epoch 152/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7900 - accuracy: 0.7943 - val_loss: 0.2207 - val_accuracy: 0.8317
# Epoch 153/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4301 - accuracy: 0.8052 - val_loss: 0.1259 - val_accuracy: 0.7923
# Epoch 154/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.4951 - accuracy: 0.7979 - val_loss: 0.8696 - val_accuracy: 0.6630
# Epoch 155/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7854 - accuracy: 0.7992 - val_loss: 0.1113 - val_accuracy: 0.8859
# Epoch 156/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4503 - accuracy: 0.8215 - val_loss: 0.3476 - val_accuracy: 0.7858
# Epoch 157/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0034 - accuracy: 0.8277 - val_loss: 0.0929 - val_accuracy: 0.8672
# Epoch 158/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6551 - accuracy: 0.7980 - val_loss: 0.2018 - val_accuracy: 0.8611
# Epoch 159/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3978 - accuracy: 0.8264 - val_loss: 0.2750 - val_accuracy: 0.5991
# Epoch 160/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4748 - accuracy: 0.8486 - val_loss: 0.1127 - val_accuracy: 0.8803
# Epoch 161/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6203 - accuracy: 0.8379 - val_loss: 0.3041 - val_accuracy: 0.8526
# Epoch 162/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8918 - accuracy: 0.8031 - val_loss: 0.6186 - val_accuracy: 0.7664
# Epoch 163/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4556 - accuracy: 0.8031 - val_loss: 0.1322 - val_accuracy: 0.8415
# Epoch 164/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4037 - accuracy: 0.8171 - val_loss: 0.5600 - val_accuracy: 0.5955
# Epoch 165/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4266 - accuracy: 0.8170 - val_loss: 0.1215 - val_accuracy: 0.8249
# Epoch 166/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0927 - accuracy: 0.7946 - val_loss: 0.2200 - val_accuracy: 0.7061
# Epoch 167/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.3583 - accuracy: 0.8486 - val_loss: 0.0795 - val_accuracy: 0.8427
# Epoch 168/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3221 - accuracy: 0.8225 - val_loss: 0.2288 - val_accuracy: 0.8067
# Epoch 169/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9905 - accuracy: 0.8121 - val_loss: 0.2215 - val_accuracy: 0.6759
# Epoch 170/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9141 - accuracy: 0.8221 - val_loss: 0.2375 - val_accuracy: 0.6537
# Epoch 171/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1397 - accuracy: 0.7849 - val_loss: 0.1233 - val_accuracy: 0.8174
# Epoch 172/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 8.9078 - accuracy: 0.8191 - val_loss: 0.1702 - val_accuracy: 0.7527
# Epoch 173/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2880 - accuracy: 0.8612 - val_loss: 0.0922 - val_accuracy: 0.8905
# Epoch 174/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1575 - accuracy: 0.8469 - val_loss: 0.1845 - val_accuracy: 0.7388
# Epoch 175/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4136 - accuracy: 0.8512 - val_loss: 0.0883 - val_accuracy: 0.7984
# Epoch 176/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4447 - accuracy: 0.8354 - val_loss: 0.0714 - val_accuracy: 0.9016
# Epoch 177/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.0212 - accuracy: 0.8081 - val_loss: 0.1658 - val_accuracy: 0.8506
# Epoch 178/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.0384 - accuracy: 0.8384 - val_loss: 0.2909 - val_accuracy: 0.7628
# Epoch 179/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3382 - accuracy: 0.8076 - val_loss: 0.2695 - val_accuracy: 0.8075
# Epoch 180/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6770 - accuracy: 0.8074 - val_loss: 0.5694 - val_accuracy: 0.7858
# Epoch 181/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7543 - accuracy: 0.8042 - val_loss: 0.1121 - val_accuracy: 0.9006
# Epoch 182/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6637 - accuracy: 0.8199 - val_loss: 0.1791 - val_accuracy: 0.6018
# Epoch 183/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4529 - accuracy: 0.8183 - val_loss: 0.0958 - val_accuracy: 0.9001
# Epoch 184/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.2923 - accuracy: 0.7907 - val_loss: 0.1310 - val_accuracy: 0.7563
# Epoch 185/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.9895 - accuracy: 0.8024 - val_loss: 0.1508 - val_accuracy: 0.8591
# Epoch 186/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5569 - accuracy: 0.8164 - val_loss: 0.1463 - val_accuracy: 0.8415
# Epoch 187/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5240 - accuracy: 0.8184 - val_loss: 0.2207 - val_accuracy: 0.7961
# Epoch 188/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.3839 - accuracy: 0.8144 - val_loss: 0.1190 - val_accuracy: 0.8525
# Epoch 189/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3962 - accuracy: 0.8322 - val_loss: 0.1071 - val_accuracy: 0.7423
# Epoch 190/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.3415 - accuracy: 0.8430 - val_loss: 0.1620 - val_accuracy: 0.7672
# Epoch 191/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5467 - accuracy: 0.8114 - val_loss: 0.2813 - val_accuracy: 0.8151
# Epoch 192/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.6728 - accuracy: 0.7984 - val_loss: 0.2857 - val_accuracy: 0.8499
# Epoch 193/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.3909 - accuracy: 0.8119 - val_loss: 0.2105 - val_accuracy: 0.7202
# Epoch 194/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8625 - accuracy: 0.8065 - val_loss: 0.5817 - val_accuracy: 0.8173
# Epoch 195/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2348 - accuracy: 0.8115 - val_loss: 0.0834 - val_accuracy: 0.8976
# Epoch 196/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 10.4972 - accuracy: 0.8120 - val_loss: 0.1029 - val_accuracy: 0.8962
# Epoch 197/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6904 - accuracy: 0.8365 - val_loss: 0.0996 - val_accuracy: 0.8976
# Epoch 198/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.1989 - accuracy: 0.8642 - val_loss: 0.2084 - val_accuracy: 0.8230
# Epoch 199/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.1792 - accuracy: 0.8591 - val_loss: 0.0838 - val_accuracy: 0.9106
# Epoch 200/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.5075 - accuracy: 0.8138 - val_loss: 0.3064 - val_accuracy: 0.7201

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
def flatten(X):
    flattened_X = np.empty((X.shape[0], X.shape[2]))  # sample x features array.
    for i in range(X.shape[0]):
        flattened_X[i] = X[i, (X.shape[1]-1), :]
    return(flattened_X)

# %%
X_test.shape
# Out:
# (14852, 16)

# %%
valid_x_predictions = model.predict([X_test, y_test])
#mse = np.mean(np.power(flatten(test_X_selected) - flatten(valid_x_predictions), 2), axis=1)

mse = np.mean(np.power(X_test - valid_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test.tolist()})
# Out:
# 465/465 [==============================] - 1s 2ms/step

# %%
error_df
# Out:
#         reconstruction_error  true_class
# 38166               0.003489           0
# 122124              0.000934           0
# 137236              0.001323           0
# 59637               0.001680           0
# 117914              3.734043           1
# ...                      ...         ...
# 30563               7.770202           1
# 148505              0.001636           0
# 125705              3.396848           1
# 132943              0.002612           0
# 49983              10.015075           1
#
# [14852 rows x 2 columns]

# %%
error_df['true_class'].value_counts()
# Out:
# 0    7720
# 1    7132
# Name: true_class, dtype: int64

# %%
import matplotlib.pyplot as plt

# 데이터프레임 준비
true_class = error_df['true_class'].astype(str)
reconstruction_error = error_df['reconstruction_error']

# 박스 플롯 그리기
plt.figure(figsize=(8, 8))
plt.boxplot(
    [reconstruction_error[true_class == cls] for cls in sorted(true_class.unique())],
    labels=sorted(true_class.unique()),
    showfliers=False,
    vert=True,
    patch_artist=True
)

plt.ylabel('Distribution')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_9437/349485020.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
print(error_df)
# Out:
#         reconstruction_error  true_class
# 38166               0.003489           0
# 122124              0.000934           0
# 137236              0.001323           0
# 59637               0.001680           0
# 117914              3.734043           1
# ...                      ...         ...
# 30563               7.770202           1
# 148505              0.001636           0
# 125705              3.396848           1
# 132943              0.002612           0
# 49983              10.015075           1
#
# [14852 rows x 2 columns]

# %%
print(error_df[(error_df['reconstruction_error'] >= 3) & (error_df['true_class'] == 0)].count())
# Out:
# reconstruction_error    21
# true_class              21
# dtype: int64

# %%
print(error_df[(error_df['reconstruction_error'] < 3) & (error_df['true_class'] == 1)].count())
# Out:
# reconstruction_error    259
# true_class              259
# dtype: int64

# %%
# 그래프 보고 threshold 결정
threshold = 0.4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes with a specified y-axis limit
plt.figure(figsize=(8, 6))

# Add jitter to avoid overlapping points in the scatter plot
x_0 = np.random.normal(1, 0.04, size=len(true_class_0))  # Jitter for class 0
x_1 = np.random.normal(2, 0.04, size=len(true_class_1))  # Jitter for class 1

# Create the scatter plot
plt.scatter(x_0, true_class_0, color='orange', alpha=0.6, edgecolor='black', label='Class 0')
plt.scatter(x_1, true_class_1, color='blue', alpha=0.6, edgecolor='black', label='Class 1')

# Set y-axis limit
plt.ylim(0, 4)

# Set x-axis labels and adjust ticks
plt.xticks([1, 2], ['0', '1'])
plt.xlabel('True Class')

# Set y-axis label and title
plt.ylabel('Reconstruction Error')
plt.title('Reconstruction Error by True Class')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 8))

# Create a swarm plot equivalent using scatter plot with more jitter
x_0 = np.random.normal(1, 0.1, size=len(true_class_0))  # Increased jitter for class 0
x_1 = np.random.normal(2, 0.1, size=len(true_class_1))  # Increased jitter for class 1

ax.scatter(x_0, true_class_0, color='blue', alpha=0.6, label='Class 0', edgecolor='w', s=50)
ax.scatter(x_1, true_class_1, color='orange', alpha=0.6, label='Class 1', edgecolor='w', s=50)

# Create boxplots
ax.boxplot([true_class_0, true_class_1], positions=[1, 2], widths=0.6, patch_artist=True, 
           showfliers=False, boxprops=dict(facecolor='None', color='black'),
           medianprops=dict(color='black'), whiskerprops=dict(color='black'))

# Set x-axis labels
ax.set_xticks([1, 2])
ax.set_xticklabels(['Class 0', 'Class 1'])

# Add a horizontal line at the threshold
ax.axhline(y=0.03, xmin=0.0, xmax=1, dashes=(5, 5), color='red')

# Adjust y-axis limit to make sure the threshold line is visible
#ax.set_ylim(bottom=min(min(true_class_0), min(true_class_1)) - 0.01, 
#           top=max(max(true_class_0), max(true_class_1)) + 0.01)
ax.set_ylim(bottom=0, top=10)
    
# Set labels and title
ax.set_ylabel('Reconstruction Error')
ax.set_title('Reconstruction Error by Class')

plt.show()

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='^', ms=3.5, linestyle='',
            label= "Normal" if name == 0 else "Fall")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.set_ylim(0, 4)
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
import numpy as np
from sklearn.metrics import f1_score

# Define the range of threshold values
threshold_range = np.arange(0.0001, 10, 0.001)

# List to store F1 scores for each threshold
f1_scores = []

# Loop through each threshold and calculate F1 score
for threshold in threshold_range:
    y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
    f1 = f1_score(error_df.true_class, y_pred)
    f1_scores.append(f1)

# Find the threshold with the highest F1 score
best_threshold = threshold_range[np.argmax(f1_scores)]
best_f1_score = max(f1_scores)

print(f"Best threshold: {best_threshold}")
print(f"Best F1 score: {best_f1_score}")

# Optionally, you can plot the F1 scores across the threshold range
plt.plot(threshold_range, f1_scores, marker='o')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Threshold')
plt.show()
# Out:
# Best threshold: 1.3501
# Best F1 score: 0.9982504024074463

# %%
# 그래프 보고 threshold 결정
threshold =  6.3050999999999995

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Assuming you have already defined LABELS, threshold, and y_pred

LABELS = ["Attack", "Normal"]

y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

# Create the figure and axis
plt.figure(figsize=(12, 12))
fig, ax = plt.subplots()

# Plot the confusion matrix using imshow
cax = ax.matshow(conf_matrix, cmap=plt.cm.Blues)

# Add color bar
plt.colorbar(cax)

# Set the labels for the axes
ax.set_xticks(np.arange(len(LABELS)))
ax.set_yticks(np.arange(len(LABELS)))

ax.set_xticklabels(LABELS)
ax.set_yticklabels(LABELS)

# Set labels and title
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.title('Confusion matrix')

# Annotate the confusion matrix with the counts
for i in range(len(LABELS)):
    for j in range(len(LABELS)):
        ax.text(j, i, format(conf_matrix[i, j], 'd'),
                ha="center", va="center",
                color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

precision, recall, f1,_ = precision_recall_fscore_support(y_test,y_pred,average='binary')
print ('Accuracy Score :',accuracy_score(error_df.true_class, y_pred) )
print ('Precision :',precision )
print ('Recall :',recall )
print ('F1 :',f1 )
# Out:
# Accuracy Score : 0.7086587664960948
# Precision : 0.9947089947089947
# Recall : 0.3954010095344924
# F1 : 0.5658673622955753

# %%
from sklearn.metrics import roc_curve, auc

# Assuming y_test and reconstruction_error have been defined
fpr, tpr, thresholds = roc_curve(y_test, reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Extract the true labels and reconstruction errors from error_df
y_true = error_df['true_class']
y_scores = error_df['reconstruction_error']

# Compute the False Positive Rate (FPR) and True Positive Rate (TPR) for different thresholds
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')

# Set plot labels and title
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")

# Display the plot
plt.show()

# %%
print(f"ROC Score : {roc_auc}")
# Out:
# ROC Score : 0.9982332783136066

# %%
# If error_df.true_class is a nested structure, flatten it
y_test = error_df.true_class.apply(lambda x: int(x[0][0]) if isinstance(x, list) else int(x))

# Ensure y_pred is a list of integers
y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]

# Now calculate the metrics
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Accuracy Score:', accuracy_score(y_test, y_pred))
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy Score: 0.7086587664960948
# Precision: 0.9947089947089947
# Recall: 0.3954010095344924
# F1 Score: 0.5658673622955753
