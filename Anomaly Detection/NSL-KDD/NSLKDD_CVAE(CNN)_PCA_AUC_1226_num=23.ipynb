# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# Out:
# 2024-12-30 03:34:34.546926: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-30 03:34:34.547001: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-30 03:34:34.547046: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-30 03:34:34.557313: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !pip install --upgrade matplotlib seaborn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/work/.local/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /home/work/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.3.post1)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.losses import mse, binary_crossentropy, kl_divergence
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import scale


import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('../newKDDTrain+.txt', header=None)

columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
train_df.columns = columns

train_df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate    class
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  anomaly
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
test_df = pd.read_csv('../newKDDTest+.txt', header=None)

test_columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
test_df.columns = columns

test_df.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  86
# 3               0       0    0  ...                  57
# 4               0       0    0  ...                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate    class
# 0                      1.00  anomaly
# 1                      1.00  anomaly
# 2                      0.00   normal
# 3                      0.00  anomaly
# 4                      0.71  anomaly
#
# [5 rows x 42 columns]

# %%
df = pd.concat([train_df, test_df])

# %%
df['class']
# Out:
# 0         normal
# 1         normal
# 2        anomaly
# 3         normal
# 4         normal
#           ...
# 22539     normal
# 22540     normal
# 22541    anomaly
# 22542     normal
# 22543    anomaly
# Name: class, Length: 148517, dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
len(df.columns)
# Out:
# 42

# %%
df.shape
# Out:
# (148517, 42)

# %%
# 'label' 열의 값이 'normal.'이면 0으로, 'normal.'이 아니면 1로 변경
df['class'] = df['class'].apply(lambda x: 0 if x == 'normal' else 1)

# 변경된 데이터프레임 확인
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding 적용
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['service'] = label_encoder.fit_transform(df['service'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# 인코딩된 데이터프레임 확인
print(df.head())
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       20     9        491          0     0
# 1         0              2       44     9        146          0     0
# 2         0              1       49     5          0          0     0
# 3         0              1       24     9        232       8153     0
# 4         0              1       24     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (148517, 42)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

tmp = df.drop(labels = 'class',axis=1)
labels = df['class']

# 1. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(tmp)

# 2. PCA 적용 (주성분 개수 설정)
n_components = 23  # 원하는 차원 수로 설정
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)


# 3. PCA 누적 분산 비율 확인
explained_variance_ratio = pca.explained_variance_ratio_.cumsum()
print("누적 분산 비율 (cumulative explained variance):")
print(explained_variance_ratio)

# 4. PCA 결과를 DataFrame으로 변환하고 label 병합
X_pca_df = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(n_components)])
df_merged = X_pca_df.assign(label=labels.values)

# 열 이름 변경 (label -> class)
df_merged.rename(columns={'label': 'class'}, inplace=True)


# 5. 병합된 데이터 타입 확인
print("Label 데이터 타입:", df_merged['class'].dtype)

# 6. 정렬 여부 확인 (필요하면 추가)
# 확인 예시: 병합 전후 `labels` 순서와 `df_merged['label']`이 동일한지 점검
assert np.array_equal(labels.values, df_merged['class'].values), "Label 순서가 일치하지 않습니다."

# 7. PCA 결과 시각화 (2D로 줄인 경우)
import matplotlib.pyplot as plt
if n_components >= 2:
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.5)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title('PCA 결과 시각화')
    plt.colorbar(label='Label')
    plt.show()
# Out:
# 누적 분산 비율 (cumulative explained variance):
# [0.18919362 0.317851   0.38738707 0.43961021 0.4865     0.52882691
#  0.5676753  0.60102599 0.62934356 0.65603097 0.68175274 0.70731433
#  0.73231683 0.75726586 0.78210081 0.80684803 0.83054577 0.85362758
#  0.87282535 0.89117939 0.90691815 0.92178925 0.93424173]
# Label 데이터 타입: int64
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#엘보우 방법
import matplotlib.pyplot as plt

# 각 주성분의 분산 비율
explained_variance_ratio = pca.explained_variance_ratio_

# 시각화
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
# 누적 분산 비율 계산
cumulative_variance_ratio = pca.explained_variance_ratio_.cumsum()

# 누적 분산 비율 출력
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance Ratio')
plt.grid()
plt.show()

# %%
# X_pca를 DataFrame으로 변환
X_pca_df = pd.DataFrame(X_pca)

# `assign`으로 label 추가
df_merged = X_pca_df.assign(label=df['class'].values)

# %%
df = df_merged

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.937416 -0.099287 -0.033490  0.114524 -0.112026  0.446328 -0.370811
# 1  0.685951  0.530801  0.084341 -0.314059  0.079046  2.454923 -3.183684
# 2  3.557238 -2.531658  0.044006  0.309697 -0.259197 -0.446973 -0.130156
# 3 -2.613555 -0.501687 -0.070456  0.034864 -0.304282 -1.015090  0.093341
# 4 -2.403517 -0.363544 -0.127620 -1.076496  0.106070 -0.662833  0.163658
#
#           7         8         9  ...        14        15        16        17  \
# 0  0.123424  0.165007  0.209009  ... -0.109289  0.113774 -0.159972 -0.213420
# 1  0.747472 -0.687930 -0.280959  ...  0.153965 -0.076350 -0.262860 -0.348073
# 2  0.014142  0.166661  0.091612  ... -0.047812  0.020766 -0.031099 -0.034055
# 3  0.047632  0.012303 -0.235638  ...  0.042842  0.049510 -0.147940 -0.022232
# 4 -0.015152 -0.018131 -0.343138  ...  0.103211 -0.095108 -0.034632  0.016427
#
#          18        19        20        21        22  label
# 0  0.607657 -0.289703 -0.154746  0.252343 -1.401422      0
# 1  1.279440  0.372077 -1.344558  0.561139 -1.305739      0
# 2 -0.207653  0.118250 -0.291462  0.043789  0.080845      1
# 3  0.199031 -0.887815 -0.019913 -0.091877  0.909842      0
# 4 -0.411946 -0.088896  0.453857 -0.088152 -0.405427      0
#
# [5 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df, test_size=0.1, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((133665, 24), (14852, 24))

# %%
X_train_normal = X_train[X_train['label'] == 0]
X_train_normal.shape

X_test_normal = X_test[X_test['label'] == 0]
X_test_normal.shape
# Out:
# (7720, 24)

# %%
y_train_normal = X_train_normal['label']
X_train_normal = X_train_normal.drop(labels='label',axis=1)

y_test_normal = X_test_normal['label']
X_test_normal = X_test_normal.drop(labels='label',axis=1)

# %%
y_test = X_test['label']
X_test = X_test.drop(labels='label', axis=1)

# %%
# !pip install keras_self_attention
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_self_attention in /home/work/.local/lib/python3.10/site-packages (0.51.0)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (from keras_self_attention) (1.26.4)

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector, Conv1D, Conv1DTranspose
from keras.models import Model
from keras import regularizers
from keras_self_attention import SeqWeightedAttention, SeqSelfAttention
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
from tensorflow.keras import layers, losses, Model, Input
import numpy as np
from tensorflow.keras import backend as K

latent_dim = 10
inter_dim = 20

# Sampling function for reparameterization trick
def sampling(args):
    z_mean, z_log_sigma = args
    batch_size = tf.shape(z_mean)[0]
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=1.)
    return z_mean + z_log_sigma * epsilon

def vae_loss(x, x_decoded_mean, z_mean, z_log_sigma):
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean), axis=1)
    kl_loss = -0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma), axis=-1)
    kl_loss_weighted = kl_loss * 0.001  # KL 다이버전스 손실에 가중치 부여
    total_loss = K.mean(reconstruction_loss + kl_loss_weighted)
    return total_loss

def cvae(X, labels):
    features = X.shape[1]  # 2D 데이터이므로 timesteps는 필요 없고, features만 사용
    input_x = Input(shape=(features,), name='InputFeatures')  # 2D 입력 (샘플, 특징)

    input_label = Input(shape=(1,), name='InputLabel')  # Assumes binary or multi-class label

    # Embed the label into the same shape as the input
    embedded_label = layers.Embedding(input_dim=2, output_dim=features)(input_label)  # Adjust output_dim to match features
    embedded_label = layers.Flatten()(embedded_label)

    # Concatenate input_x and embedded_label
    concatenated_input = layers.Concatenate()([input_x, embedded_label])

    # Reshape for Conv1D layer (to 3D)
    reshaped_input = layers.Reshape((features + embedded_label.shape[-1], 1))(concatenated_input)

    # Encoder with CNN layers
    h = layers.Conv1D(filters=64, kernel_size=3, activation="relu", padding='same')(reshaped_input)
    h = layers.Conv1D(filters=32, kernel_size=3, activation="relu", padding='same')(h)
    h = layers.Conv1D(filters=16, kernel_size=3, activation="relu", padding='same')(h)

    # Flatten for dense layers (MLP)
    h = layers.Flatten()(h)
    h = layers.Dense(inter_dim, activation='relu')(h)
    h = layers.Dense(inter_dim, activation='relu')(h)

    # z layer
    z_mean = layers.Dense(latent_dim)(h)
    z_log_sigma = layers.Dense(latent_dim)(h)
    z = layers.Lambda(sampling)([z_mean, z_log_sigma])

    # Decoder
    # Add the label to the latent space z
    z_with_label = layers.Concatenate()([z, embedded_label])

    # Expand for Conv1DTranspose layer
    decoder1 = layers.Dense((features + embedded_label.shape[-1]) * inter_dim)(z_with_label)
    decoder1 = layers.Reshape((features + embedded_label.shape[-1], inter_dim))(decoder1)

    # Decoder with CNN layers
    decoder1 = layers.Conv1DTranspose(filters=16, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=32, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=64, kernel_size=3, activation="relu", padding='same')(decoder1)

    # Flatten and final dense layer to reconstruct original features
    decoder1 = layers.Flatten()(decoder1)
    decoder1 = layers.Dense(features)(decoder1)
    
    model = Model([input_x, input_label], decoder1)
    model.add_loss(vae_loss(input_x, decoder1, z_mean, z_log_sigma))
    
    return model

# Create CVAE model
model = cvae(X_train_normal, y_train_normal)
model.summary()

# Compile and train the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy'])
history = model.fit([X_train_normal, y_train_normal], X_train_normal,
                    shuffle=True,
                    epochs=200, 
                    validation_split=0.1,  
                    batch_size=32).history
# Out:
# 2024-12-30 03:34:51.274987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:4c:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  InputLabel (InputLayer)     [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 23)                46        ['InputLabel[0][0]']
#
#  InputFeatures (InputLayer)  [(None, 23)]                 0         []
#
#  flatten (Flatten)           (None, 23)                   0         ['embedding[0][0]']
#
#  concatenate (Concatenate)   (None, 46)                   0         ['InputFeatures[0][0]',
#                                                                      'flatten[0][0]']
#
#  reshape (Reshape)           (None, 46, 1)                0         ['concatenate[0][0]']
#
#  conv1d (Conv1D)             (None, 46, 64)               256       ['reshape[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 46, 32)               6176      ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 46, 16)               1552      ['conv1d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 736)                  0         ['conv1d_2[0][0]']
#
#  dense (Dense)               (None, 20)                   14740     ['flatten_1[0][0]']
#
#  dense_1 (Dense)             (None, 20)                   420       ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 10)                   0         ['dense_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 33)                   0         ['lambda[0][0]',
#  )                                                                   'flatten[0][0]']
#
#  dense_4 (Dense)             (None, 920)                  31280     ['concatenate_1[0][0]']
#
#  reshape_1 (Reshape)         (None, 46, 20)               0         ['dense_4[0][0]']
#
#  conv1d_transpose (Conv1DTr  (None, 46, 16)               976       ['reshape_1[0][0]']
#  anspose)
#
#  conv1d_transpose_1 (Conv1D  (None, 46, 32)               1568      ['conv1d_transpose[0][0]']
#  Transpose)
#
#  conv1d_transpose_2 (Conv1D  (None, 46, 64)               6208      ['conv1d_transpose_1[0][0]']
#  Transpose)
#
#  flatten_2 (Flatten)         (None, 2944)                 0         ['conv1d_transpose_2[0][0]']
#
#  dense_5 (Dense)             (None, 23)                   67735     ['flatten_2[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['dense_3[0][0]']
#  Lambda)
#
#  tf.math.square_1 (TFOpLamb  (None, 10)                   0         ['dense_2[0][0]']
#  da)
#
#  tf.math.subtract_1 (TFOpLa  (None, 10)                   0         ['tf.__operators__.add[0][0]',
#  mbda)                                                               'tf.math.square_1[0][0]']
#
#  tf.math.exp (TFOpLambda)    (None, 10)                   0         ['dense_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 10)                   0         ['tf.math.subtract_1[0][0]',
#  mbda)                                                               'tf.math.exp[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 23)                   0         ['InputFeatures[0][0]',
#  da)                                                                 'dense_5[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None,)                      0         ['tf.math.subtract_2[0][0]']
#  Lambda)
#
#  tf.math.square (TFOpLambda  (None, 23)                   0         ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.math.reduce_sum_1[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLa  (None,)                      0         ['tf.math.square[0][0]']
#  mbda)
#
#  tf.math.multiply_1 (TFOpLa  (None,)                      0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.__operators__.add_1 (TF  (None,)                      0         ['tf.math.reduce_sum[0][0]',
#  OpLambda)                                                           'tf.math.multiply_1[0][0]']
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.__operators__.add_1[0][0]
#  ambda)                                                             ']
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 131377 (513.19 KB)
# Trainable params: 131377 (513.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 2024-12-30 03:34:53.438514: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-12-30 03:34:54.049020: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f96ee734e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-30 03:34:54.049082: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2024-12-30 03:34:54.054081: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-30 03:34:54.137178: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1950/1950 [==============================] - 15s 6ms/step - loss: 9019587.0000 - accuracy: 0.7209 - val_loss: 2.0405 - val_accuracy: 0.8331
# Epoch 2/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1170745.7500 - accuracy: 0.8473 - val_loss: 1.9546 - val_accuracy: 0.8281
# Epoch 3/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 151.7623 - accuracy: 0.8534 - val_loss: 1.1067 - val_accuracy: 0.8868
# Epoch 4/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9521 - accuracy: 0.8771 - val_loss: 0.9693 - val_accuracy: 0.8842
# Epoch 5/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.9731 - accuracy: 0.8889 - val_loss: 6.9801 - val_accuracy: 0.7583
# Epoch 6/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 14.8198 - accuracy: 0.8621 - val_loss: 0.5709 - val_accuracy: 0.8952
# Epoch 7/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.8868 - accuracy: 0.8856 - val_loss: 0.5524 - val_accuracy: 0.8917
# Epoch 8/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.1966 - accuracy: 0.8964 - val_loss: 2.1300 - val_accuracy: 0.8753
# Epoch 9/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9135 - accuracy: 0.8897 - val_loss: 2.2596 - val_accuracy: 0.8799
# Epoch 10/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2816 - accuracy: 0.9018 - val_loss: 0.7409 - val_accuracy: 0.9047
# Epoch 11/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.9619 - accuracy: 0.9077 - val_loss: 0.8343 - val_accuracy: 0.8946
# Epoch 12/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 4.2581 - accuracy: 0.8989 - val_loss: 0.4873 - val_accuracy: 0.9028
# Epoch 13/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.2072 - accuracy: 0.9111 - val_loss: 0.3474 - val_accuracy: 0.9116
# Epoch 14/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.9556 - accuracy: 0.9140 - val_loss: 0.3190 - val_accuracy: 0.9214
# Epoch 15/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.0159 - accuracy: 0.9137 - val_loss: 0.3656 - val_accuracy: 0.9194
# Epoch 16/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.4192 - accuracy: 0.9095 - val_loss: 0.2913 - val_accuracy: 0.9315
# Epoch 17/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.1002 - accuracy: 0.9079 - val_loss: 0.7293 - val_accuracy: 0.8516
# Epoch 18/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2028 - accuracy: 0.9206 - val_loss: 0.5752 - val_accuracy: 0.8809
# Epoch 19/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.0909 - accuracy: 0.9125 - val_loss: 2.6049 - val_accuracy: 0.8428
# Epoch 20/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 5.7594 - accuracy: 0.9009 - val_loss: 0.5447 - val_accuracy: 0.9273
# Epoch 21/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 4.5609 - accuracy: 0.8977 - val_loss: 0.4144 - val_accuracy: 0.9058
# Epoch 22/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.2601 - accuracy: 0.9093 - val_loss: 0.8321 - val_accuracy: 0.8928
# Epoch 23/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 33.2509 - accuracy: 0.8947 - val_loss: 0.4532 - val_accuracy: 0.9301
# Epoch 24/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.1153 - accuracy: 0.9114 - val_loss: 0.4893 - val_accuracy: 0.9250
# Epoch 25/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.9248 - accuracy: 0.9212 - val_loss: 0.6895 - val_accuracy: 0.9292
# Epoch 26/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.6621 - accuracy: 0.9223 - val_loss: 0.5622 - val_accuracy: 0.9272
# Epoch 27/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.0936 - accuracy: 0.9021 - val_loss: 1.1583 - val_accuracy: 0.8956
# Epoch 28/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 4.1373 - accuracy: 0.9187 - val_loss: 0.7136 - val_accuracy: 0.8967
# Epoch 29/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6341 - accuracy: 0.9062 - val_loss: 0.4451 - val_accuracy: 0.9188
# Epoch 30/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 7.0731 - accuracy: 0.9098 - val_loss: 1.0522 - val_accuracy: 0.8650
# Epoch 31/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 4.3344 - accuracy: 0.9118 - val_loss: 0.2980 - val_accuracy: 0.9211
# Epoch 32/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.3882 - accuracy: 0.9194 - val_loss: 0.4729 - val_accuracy: 0.9244
# Epoch 33/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.4921 - accuracy: 0.9284 - val_loss: 0.7594 - val_accuracy: 0.9213
# Epoch 34/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.0619 - accuracy: 0.9308 - val_loss: 0.4880 - val_accuracy: 0.9241
# Epoch 35/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.8851 - accuracy: 0.9293 - val_loss: 0.7821 - val_accuracy: 0.9262
# Epoch 36/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 236.2380 - accuracy: 0.9178 - val_loss: 0.4404 - val_accuracy: 0.9185
# Epoch 37/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.6784 - accuracy: 0.9337 - val_loss: 0.3033 - val_accuracy: 0.9311
# Epoch 38/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7111 - accuracy: 0.9415 - val_loss: 0.2902 - val_accuracy: 0.9338
# Epoch 39/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.3209 - accuracy: 0.9393 - val_loss: 0.2529 - val_accuracy: 0.9462
# Epoch 40/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8247 - accuracy: 0.9453 - val_loss: 0.2415 - val_accuracy: 0.9479
# Epoch 41/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7259 - accuracy: 0.9451 - val_loss: 0.2012 - val_accuracy: 0.9500
# Epoch 42/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.7092 - accuracy: 0.9488 - val_loss: 2.2386 - val_accuracy: 0.9067
# Epoch 43/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9579 - accuracy: 0.9258 - val_loss: 0.2584 - val_accuracy: 0.9423
# Epoch 44/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6564 - accuracy: 0.9298 - val_loss: 0.2583 - val_accuracy: 0.9502
# Epoch 45/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.8116 - accuracy: 0.9431 - val_loss: 0.4075 - val_accuracy: 0.9458
# Epoch 46/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.5067 - accuracy: 0.9334 - val_loss: 0.2126 - val_accuracy: 0.9500
# Epoch 47/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.3995 - accuracy: 0.9283 - val_loss: 0.2594 - val_accuracy: 0.9462
# Epoch 48/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.6979 - accuracy: 0.9299 - val_loss: 0.4654 - val_accuracy: 0.9322
# Epoch 49/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6625 - accuracy: 0.9328 - val_loss: 0.2425 - val_accuracy: 0.9423
# Epoch 50/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.4345 - accuracy: 0.9303 - val_loss: 0.3827 - val_accuracy: 0.9076
# Epoch 51/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.3665 - accuracy: 0.9332 - val_loss: 0.2623 - val_accuracy: 0.9514
# Epoch 52/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.7376 - accuracy: 0.9322 - val_loss: 0.3103 - val_accuracy: 0.9527
# Epoch 53/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8406 - accuracy: 0.9410 - val_loss: 0.2054 - val_accuracy: 0.9566
# Epoch 54/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5422 - accuracy: 0.9360 - val_loss: 0.2569 - val_accuracy: 0.9520
# Epoch 55/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5604 - accuracy: 0.9361 - val_loss: 0.2702 - val_accuracy: 0.9324
# Epoch 56/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3141 - accuracy: 0.9382 - val_loss: 0.6046 - val_accuracy: 0.9171
# Epoch 57/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.6484 - accuracy: 0.9333 - val_loss: 0.3356 - val_accuracy: 0.9399
# Epoch 58/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 2.6312 - accuracy: 0.9403 - val_loss: 8.5089 - val_accuracy: 0.8640
# Epoch 59/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0727 - accuracy: 0.9319 - val_loss: 0.4529 - val_accuracy: 0.9475
# Epoch 60/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.4728 - accuracy: 0.9409 - val_loss: 0.7057 - val_accuracy: 0.9384
# Epoch 61/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1044.9617 - accuracy: 0.9344 - val_loss: 0.3489 - val_accuracy: 0.9123
# Epoch 62/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.8961 - accuracy: 0.9298 - val_loss: 0.2113 - val_accuracy: 0.9410
# Epoch 63/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0170 - accuracy: 0.9384 - val_loss: 0.7323 - val_accuracy: 0.9348
# Epoch 64/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.8639 - accuracy: 0.9364 - val_loss: 0.2247 - val_accuracy: 0.9266
# Epoch 65/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.9598 - accuracy: 0.9445 - val_loss: 0.1836 - val_accuracy: 0.9505
# Epoch 66/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8346 - accuracy: 0.9461 - val_loss: 0.3539 - val_accuracy: 0.9404
# Epoch 67/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.2919 - accuracy: 0.9416 - val_loss: 0.2532 - val_accuracy: 0.9273
# Epoch 68/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.2586 - accuracy: 0.9345 - val_loss: 0.4979 - val_accuracy: 0.9205
# Epoch 69/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.4943 - accuracy: 0.9450 - val_loss: 0.2012 - val_accuracy: 0.9606
# Epoch 70/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6146 - accuracy: 0.9417 - val_loss: 0.2848 - val_accuracy: 0.9573
# Epoch 71/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3822 - accuracy: 0.9441 - val_loss: 0.1957 - val_accuracy: 0.9580
# Epoch 72/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8911 - accuracy: 0.9377 - val_loss: 0.3839 - val_accuracy: 0.9351
# Epoch 73/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.9423 - accuracy: 0.9315 - val_loss: 0.2468 - val_accuracy: 0.9462
# Epoch 74/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9165 - accuracy: 0.9366 - val_loss: 0.2050 - val_accuracy: 0.9513
# Epoch 75/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.0529 - accuracy: 0.9450 - val_loss: 0.4179 - val_accuracy: 0.9491
# Epoch 76/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.9559 - accuracy: 0.9433 - val_loss: 0.2294 - val_accuracy: 0.9621
# Epoch 77/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.8267 - accuracy: 0.9485 - val_loss: 0.3498 - val_accuracy: 0.9464
# Epoch 78/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.7853 - accuracy: 0.9402 - val_loss: 0.2216 - val_accuracy: 0.9596
# Epoch 79/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 4.1961 - accuracy: 0.9301 - val_loss: 0.2918 - val_accuracy: 0.9403
# Epoch 80/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.1115 - accuracy: 0.9400 - val_loss: 0.3513 - val_accuracy: 0.9433
# Epoch 81/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 4.1188 - accuracy: 0.9387 - val_loss: 0.5333 - val_accuracy: 0.9250
# Epoch 82/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.1244 - accuracy: 0.9466 - val_loss: 0.2326 - val_accuracy: 0.9585
# Epoch 83/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.8182 - accuracy: 0.9441 - val_loss: 0.3069 - val_accuracy: 0.9481
# Epoch 84/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.7834 - accuracy: 0.9428 - val_loss: 1.5139 - val_accuracy: 0.9355
# Epoch 85/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.6666 - accuracy: 0.9405 - val_loss: 0.2402 - val_accuracy: 0.9564
# Epoch 86/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.4211 - accuracy: 0.9431 - val_loss: 0.4861 - val_accuracy: 0.9327
# Epoch 87/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7900 - accuracy: 0.9512 - val_loss: 0.3741 - val_accuracy: 0.9462
# Epoch 88/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.5123 - accuracy: 0.9437 - val_loss: 0.3497 - val_accuracy: 0.9484
# Epoch 89/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.1464 - accuracy: 0.9375 - val_loss: 0.1922 - val_accuracy: 0.9566
# Epoch 90/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.5096 - accuracy: 0.9474 - val_loss: 0.2136 - val_accuracy: 0.9560
# Epoch 91/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 5.3682 - accuracy: 0.9413 - val_loss: 0.3348 - val_accuracy: 0.9425
# Epoch 92/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.1595 - accuracy: 0.9474 - val_loss: 0.2358 - val_accuracy: 0.9554
# Epoch 93/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4995 - accuracy: 0.9435 - val_loss: 0.1937 - val_accuracy: 0.9588
# Epoch 94/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5899 - accuracy: 0.9542 - val_loss: 0.5627 - val_accuracy: 0.9065
# Epoch 95/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.9156 - accuracy: 0.9434 - val_loss: 0.1914 - val_accuracy: 0.9645
# Epoch 96/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 0.6881 - accuracy: 0.9493 - val_loss: 0.4708 - val_accuracy: 0.9133
# Epoch 97/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.6713 - accuracy: 0.9450 - val_loss: 0.2671 - val_accuracy: 0.9541
# Epoch 98/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1472 - accuracy: 0.9462 - val_loss: 0.2007 - val_accuracy: 0.9527
# Epoch 99/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.4960 - accuracy: 0.9416 - val_loss: 0.1914 - val_accuracy: 0.9521
# Epoch 100/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 5.7355 - accuracy: 0.9405 - val_loss: 0.4522 - val_accuracy: 0.9224
# Epoch 101/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.6840 - accuracy: 0.9463 - val_loss: 0.2225 - val_accuracy: 0.9511
# Epoch 102/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.8508 - accuracy: 0.9491 - val_loss: 0.1549 - val_accuracy: 0.9629
# Epoch 103/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.8294 - accuracy: 0.9409 - val_loss: 0.1666 - val_accuracy: 0.9596
# Epoch 104/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.1575 - accuracy: 0.9398 - val_loss: 0.1981 - val_accuracy: 0.9556
# Epoch 105/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8037 - accuracy: 0.9456 - val_loss: 1.7442 - val_accuracy: 0.8731
# Epoch 106/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.2459 - accuracy: 0.9337 - val_loss: 0.1771 - val_accuracy: 0.9583
# Epoch 107/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.1536 - accuracy: 0.9388 - val_loss: 0.1693 - val_accuracy: 0.9533
# Epoch 108/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.4579 - accuracy: 0.9385 - val_loss: 0.2225 - val_accuracy: 0.9465
# Epoch 109/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.1740 - accuracy: 0.9417 - val_loss: 0.1838 - val_accuracy: 0.9540
# Epoch 110/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.9779 - accuracy: 0.9412 - val_loss: 0.3983 - val_accuracy: 0.9401
# Epoch 111/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 3.8871 - accuracy: 0.9386 - val_loss: 0.2106 - val_accuracy: 0.9541
# Epoch 112/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2066 - accuracy: 0.9452 - val_loss: 0.2466 - val_accuracy: 0.9514
# Epoch 113/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.3349 - accuracy: 0.9413 - val_loss: 0.2277 - val_accuracy: 0.9430
# Epoch 114/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6076 - accuracy: 0.9429 - val_loss: 0.4497 - val_accuracy: 0.9253
# Epoch 115/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.2165 - accuracy: 0.9365 - val_loss: 1.5960 - val_accuracy: 0.7773
# Epoch 116/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 6.7286 - accuracy: 0.9278 - val_loss: 0.3071 - val_accuracy: 0.9316
# Epoch 117/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.9052 - accuracy: 0.9331 - val_loss: 0.2193 - val_accuracy: 0.9429
# Epoch 118/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.9394 - accuracy: 0.9367 - val_loss: 0.2558 - val_accuracy: 0.9381
# Epoch 119/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.6345 - accuracy: 0.9442 - val_loss: 0.2627 - val_accuracy: 0.9507
# Epoch 120/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.0748 - accuracy: 0.9432 - val_loss: 0.3175 - val_accuracy: 0.9523
# Epoch 121/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.5678 - accuracy: 0.9327 - val_loss: 0.3225 - val_accuracy: 0.9406
# Epoch 122/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 6.7983 - accuracy: 0.9354 - val_loss: 0.3413 - val_accuracy: 0.9606
# Epoch 123/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.7845 - accuracy: 0.9488 - val_loss: 0.2059 - val_accuracy: 0.9511
# Epoch 124/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.3265 - accuracy: 0.9430 - val_loss: 0.2439 - val_accuracy: 0.9458
# Epoch 125/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.7768 - accuracy: 0.9452 - val_loss: 0.1793 - val_accuracy: 0.9500
# Epoch 126/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.6394 - accuracy: 0.9367 - val_loss: 0.2175 - val_accuracy: 0.9601
# Epoch 127/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.4652 - accuracy: 0.9387 - val_loss: 0.2165 - val_accuracy: 0.9491
# Epoch 128/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.6650 - accuracy: 0.9433 - val_loss: 0.2604 - val_accuracy: 0.9299
# Epoch 129/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3137 - accuracy: 0.9375 - val_loss: 0.4430 - val_accuracy: 0.9401
# Epoch 130/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9404 - accuracy: 0.9413 - val_loss: 0.2194 - val_accuracy: 0.9527
# Epoch 131/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.2022 - accuracy: 0.9432 - val_loss: 0.9177 - val_accuracy: 0.9139
# Epoch 132/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 11.3279 - accuracy: 0.9272 - val_loss: 0.4285 - val_accuracy: 0.9413
# Epoch 133/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.4175 - accuracy: 0.9393 - val_loss: 0.3223 - val_accuracy: 0.9453
# Epoch 134/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.2523 - accuracy: 0.9419 - val_loss: 0.6770 - val_accuracy: 0.9449
# Epoch 135/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.6191 - accuracy: 0.9401 - val_loss: 0.1844 - val_accuracy: 0.9494
# Epoch 136/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.7163 - accuracy: 0.9497 - val_loss: 0.4677 - val_accuracy: 0.9474
# Epoch 137/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.5461 - accuracy: 0.9433 - val_loss: 0.4214 - val_accuracy: 0.9367
# Epoch 138/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.1320 - accuracy: 0.9433 - val_loss: 0.4349 - val_accuracy: 0.9598
# Epoch 139/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.2344 - accuracy: 0.9402 - val_loss: 0.2009 - val_accuracy: 0.9527
# Epoch 140/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.6881 - accuracy: 0.9361 - val_loss: 0.2752 - val_accuracy: 0.9272
# Epoch 141/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.7103 - accuracy: 0.9361 - val_loss: 0.3206 - val_accuracy: 0.9316
# Epoch 142/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3548 - accuracy: 0.9372 - val_loss: 0.1836 - val_accuracy: 0.9577
# Epoch 143/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 5.0123 - accuracy: 0.9413 - val_loss: 0.1992 - val_accuracy: 0.9569
# Epoch 144/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.0404 - accuracy: 0.9484 - val_loss: 0.1725 - val_accuracy: 0.9572
# Epoch 145/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3192 - accuracy: 0.9424 - val_loss: 0.3435 - val_accuracy: 0.9269
# Epoch 146/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.7313 - accuracy: 0.9387 - val_loss: 0.2269 - val_accuracy: 0.9476
# Epoch 147/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.7451 - accuracy: 0.9446 - val_loss: 0.3956 - val_accuracy: 0.9272
# Epoch 148/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.2489 - accuracy: 0.9395 - val_loss: 0.2409 - val_accuracy: 0.9378
# Epoch 149/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 5.8063 - accuracy: 0.9315 - val_loss: 0.2548 - val_accuracy: 0.9478
# Epoch 150/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8834 - accuracy: 0.9469 - val_loss: 0.2712 - val_accuracy: 0.9534
# Epoch 151/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3314 - accuracy: 0.9423 - val_loss: 0.2039 - val_accuracy: 0.9575
# Epoch 152/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3394 - accuracy: 0.9426 - val_loss: 0.2253 - val_accuracy: 0.9429
# Epoch 153/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.9010 - accuracy: 0.9484 - val_loss: 0.1668 - val_accuracy: 0.9416
# Epoch 154/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.2979 - accuracy: 0.9440 - val_loss: 0.8252 - val_accuracy: 0.9471
# Epoch 155/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8145 - accuracy: 0.9436 - val_loss: 0.1539 - val_accuracy: 0.9608
# Epoch 156/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.5125 - accuracy: 0.9452 - val_loss: 0.1419 - val_accuracy: 0.9606
# Epoch 157/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.0107 - accuracy: 0.9454 - val_loss: 0.2007 - val_accuracy: 0.9495
# Epoch 158/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3477 - accuracy: 0.9455 - val_loss: 0.3330 - val_accuracy: 0.9445
# Epoch 159/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7417 - accuracy: 0.9437 - val_loss: 0.3297 - val_accuracy: 0.9510
# Epoch 160/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.4488 - accuracy: 0.9446 - val_loss: 0.1657 - val_accuracy: 0.9438
# Epoch 161/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.2360 - accuracy: 0.9506 - val_loss: 0.2063 - val_accuracy: 0.9475
# Epoch 162/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5817 - accuracy: 0.9506 - val_loss: 0.2118 - val_accuracy: 0.9590
# Epoch 163/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.1876 - accuracy: 0.9441 - val_loss: 0.1979 - val_accuracy: 0.9361
# Epoch 164/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.4612 - accuracy: 0.9391 - val_loss: 0.1463 - val_accuracy: 0.9611
# Epoch 165/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 10.4935 - accuracy: 0.9436 - val_loss: 0.2245 - val_accuracy: 0.9514
# Epoch 166/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6745 - accuracy: 0.9561 - val_loss: 0.1281 - val_accuracy: 0.9631
# Epoch 167/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.6590 - accuracy: 0.9572 - val_loss: 0.1454 - val_accuracy: 0.9563
# Epoch 168/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.6334 - accuracy: 0.9545 - val_loss: 0.1471 - val_accuracy: 0.9590
# Epoch 169/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.1030 - accuracy: 0.9546 - val_loss: 0.1619 - val_accuracy: 0.9626
# Epoch 170/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4956 - accuracy: 0.9537 - val_loss: 0.1750 - val_accuracy: 0.9598
# Epoch 171/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.1539 - accuracy: 0.9459 - val_loss: 0.2084 - val_accuracy: 0.9367
# Epoch 172/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7856 - accuracy: 0.9536 - val_loss: 0.1396 - val_accuracy: 0.9654
# Epoch 173/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9128 - accuracy: 0.9528 - val_loss: 0.1430 - val_accuracy: 0.9629
# Epoch 174/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5331 - accuracy: 0.9536 - val_loss: 0.1913 - val_accuracy: 0.9629
# Epoch 175/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.6614 - accuracy: 0.9507 - val_loss: 0.1788 - val_accuracy: 0.9624
# Epoch 176/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4187 - accuracy: 0.9551 - val_loss: 0.2172 - val_accuracy: 0.9639
# Epoch 177/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6534 - accuracy: 0.9508 - val_loss: 0.1725 - val_accuracy: 0.9668
# Epoch 178/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.5338 - accuracy: 0.9527 - val_loss: 0.2176 - val_accuracy: 0.9517
# Epoch 179/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 1.2776 - accuracy: 0.9448 - val_loss: 0.3044 - val_accuracy: 0.9497
# Epoch 180/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8446 - accuracy: 0.9389 - val_loss: 0.1630 - val_accuracy: 0.9513
# Epoch 181/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.2290 - accuracy: 0.9442 - val_loss: 0.1964 - val_accuracy: 0.9521
# Epoch 182/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3685 - accuracy: 0.9388 - val_loss: 0.2199 - val_accuracy: 0.9466
# Epoch 183/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8660 - accuracy: 0.9496 - val_loss: 0.1531 - val_accuracy: 0.9576
# Epoch 184/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5527 - accuracy: 0.9482 - val_loss: 0.1482 - val_accuracy: 0.9547
# Epoch 185/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5292 - accuracy: 0.9481 - val_loss: 0.1951 - val_accuracy: 0.9515
# Epoch 186/200
# 1950/1950 [==============================] - 12s 6ms/step - loss: 2.3863 - accuracy: 0.9513 - val_loss: 0.1545 - val_accuracy: 0.9613
# Epoch 187/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4599 - accuracy: 0.9547 - val_loss: 1.2836 - val_accuracy: 0.9350
# Epoch 188/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9413 - accuracy: 0.9447 - val_loss: 0.1960 - val_accuracy: 0.9599
# Epoch 189/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9741 - accuracy: 0.9464 - val_loss: 0.1875 - val_accuracy: 0.9589
# Epoch 190/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3191 - accuracy: 0.9398 - val_loss: 0.2474 - val_accuracy: 0.9419
# Epoch 191/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3454 - accuracy: 0.9426 - val_loss: 0.1979 - val_accuracy: 0.9567
# Epoch 192/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5218 - accuracy: 0.9485 - val_loss: 0.2273 - val_accuracy: 0.9611
# Epoch 193/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.8503 - accuracy: 0.9456 - val_loss: 0.1920 - val_accuracy: 0.9515
# Epoch 194/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 5.2537 - accuracy: 0.9453 - val_loss: 0.2230 - val_accuracy: 0.9514
# Epoch 195/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.1942 - accuracy: 0.9535 - val_loss: 0.1316 - val_accuracy: 0.9612
# Epoch 196/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9401 - accuracy: 0.9540 - val_loss: 0.3284 - val_accuracy: 0.9527
# Epoch 197/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5842 - accuracy: 0.9462 - val_loss: 0.1305 - val_accuracy: 0.9634
# Epoch 198/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6247 - accuracy: 0.9495 - val_loss: 0.1705 - val_accuracy: 0.9691
# Epoch 199/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0724 - accuracy: 0.9466 - val_loss: 0.1736 - val_accuracy: 0.9635
# Epoch 200/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 13.7585 - accuracy: 0.9460 - val_loss: 0.1492 - val_accuracy: 0.9539

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
def flatten(X):
    flattened_X = np.empty((X.shape[0], X.shape[2]))  # sample x features array.
    for i in range(X.shape[0]):
        flattened_X[i] = X[i, (X.shape[1]-1), :]
    return(flattened_X)

# %%
X_test.shape
# Out:
# (14852, 23)

# %%
valid_x_predictions = model.predict([X_test, y_test])
#mse = np.mean(np.power(flatten(test_X_selected) - flatten(valid_x_predictions), 2), axis=1)

mse = np.mean(np.power(X_test - valid_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test.tolist()})
# Out:
# 465/465 [==============================] - 1s 2ms/step

# %%
error_df
# Out:
#         reconstruction_error  true_class
# 38166               0.001082           0
# 122124              0.000814           0
# 137236              0.000735           0
# 59637               0.000457           0
# 117914              5.032277           1
# ...                      ...         ...
# 30563               4.939414           1
# 148505              0.000593           0
# 125705              8.020305           1
# 132943              0.001054           0
# 49983               6.730315           1
#
# [14852 rows x 2 columns]

# %%
error_df['true_class'].value_counts()
# Out:
# 0    7720
# 1    7132
# Name: true_class, dtype: int64

# %%
import matplotlib.pyplot as plt

# 데이터프레임 준비
true_class = error_df['true_class'].astype(str)
reconstruction_error = error_df['reconstruction_error']

# 박스 플롯 그리기
plt.figure(figsize=(8, 8))
plt.boxplot(
    [reconstruction_error[true_class == cls] for cls in sorted(true_class.unique())],
    labels=sorted(true_class.unique()),
    showfliers=False,
    vert=True,
    patch_artist=True
)

plt.ylabel('Distribution')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_12968/349485020.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
print(error_df)
# Out:
#         reconstruction_error  true_class
# 38166               0.001082           0
# 122124              0.000814           0
# 137236              0.000735           0
# 59637               0.000457           0
# 117914              5.032277           1
# ...                      ...         ...
# 30563               4.939414           1
# 148505              0.000593           0
# 125705              8.020305           1
# 132943              0.001054           0
# 49983               6.730315           1
#
# [14852 rows x 2 columns]

# %%
print(error_df[(error_df['reconstruction_error'] >= 3) & (error_df['true_class'] == 0)].count())
# Out:
# reconstruction_error    7
# true_class              7
# dtype: int64

# %%
print(error_df[(error_df['reconstruction_error'] < 3) & (error_df['true_class'] == 1)].count())
# Out:
# reconstruction_error    652
# true_class              652
# dtype: int64

# %%
# 그래프 보고 threshold 결정
threshold = 0.4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes with a specified y-axis limit
plt.figure(figsize=(8, 6))

# Add jitter to avoid overlapping points in the scatter plot
x_0 = np.random.normal(1, 0.04, size=len(true_class_0))  # Jitter for class 0
x_1 = np.random.normal(2, 0.04, size=len(true_class_1))  # Jitter for class 1

# Create the scatter plot
plt.scatter(x_0, true_class_0, color='orange', alpha=0.6, edgecolor='black', label='Class 0')
plt.scatter(x_1, true_class_1, color='blue', alpha=0.6, edgecolor='black', label='Class 1')

# Set y-axis limit
plt.ylim(0, 4)

# Set x-axis labels and adjust ticks
plt.xticks([1, 2], ['0', '1'])
plt.xlabel('True Class')

# Set y-axis label and title
plt.ylabel('Reconstruction Error')
plt.title('Reconstruction Error by True Class')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 8))

# Create a swarm plot equivalent using scatter plot with more jitter
x_0 = np.random.normal(1, 0.1, size=len(true_class_0))  # Increased jitter for class 0
x_1 = np.random.normal(2, 0.1, size=len(true_class_1))  # Increased jitter for class 1

ax.scatter(x_0, true_class_0, color='blue', alpha=0.6, label='Class 0', edgecolor='w', s=50)
ax.scatter(x_1, true_class_1, color='orange', alpha=0.6, label='Class 1', edgecolor='w', s=50)

# Create boxplots
ax.boxplot([true_class_0, true_class_1], positions=[1, 2], widths=0.6, patch_artist=True, 
           showfliers=False, boxprops=dict(facecolor='None', color='black'),
           medianprops=dict(color='black'), whiskerprops=dict(color='black'))

# Set x-axis labels
ax.set_xticks([1, 2])
ax.set_xticklabels(['Class 0', 'Class 1'])

# Add a horizontal line at the threshold
ax.axhline(y=0.03, xmin=0.0, xmax=1, dashes=(5, 5), color='red')

# Adjust y-axis limit to make sure the threshold line is visible
#ax.set_ylim(bottom=min(min(true_class_0), min(true_class_1)) - 0.01, 
#           top=max(max(true_class_0), max(true_class_1)) + 0.01)
ax.set_ylim(bottom=0, top=10)
    
# Set labels and title
ax.set_ylabel('Reconstruction Error')
ax.set_title('Reconstruction Error by Class')

plt.show()

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='^', ms=3.5, linestyle='',
            label= "Normal" if name == 0 else "Fall")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.set_ylim(0, 4)
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
import numpy as np
from sklearn.metrics import f1_score

# Define the range of threshold values
threshold_range = np.arange(0.1, 10, 0.1)

# List to store F1 scores for each threshold
f1_scores = []

# Loop through each threshold and calculate F1 score
for threshold in threshold_range:
    y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
    f1 = f1_score(error_df.true_class, y_pred)
    f1_scores.append(f1)

# Find the threshold with the highest F1 score
best_threshold = threshold_range[np.argmax(f1_scores)]
best_f1_score = max(f1_scores)

print(f"Best threshold: {best_threshold}")
print(f"Best F1 score: {best_f1_score}")

# Optionally, you can plot the F1 scores across the threshold range
plt.plot(threshold_range, f1_scores, marker='o')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Threshold')
plt.show()
# Out:
# Best threshold: 0.7000000000000001
# Best F1 score: 0.9988795518207283

# %%
# 그래프 보고 threshold 결정
threshold = 0.7000000000000001

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Assuming you have already defined LABELS, threshold, and y_pred

LABELS = ["Attack", "Normal"]

y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

# Create the figure and axis
plt.figure(figsize=(12, 12))
fig, ax = plt.subplots()

# Plot the confusion matrix using imshow
cax = ax.matshow(conf_matrix, cmap=plt.cm.Blues)

# Add color bar
plt.colorbar(cax)

# Set the labels for the axes
ax.set_xticks(np.arange(len(LABELS)))
ax.set_yticks(np.arange(len(LABELS)))

ax.set_xticklabels(LABELS)
ax.set_yticklabels(LABELS)

# Set labels and title
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.title('Confusion matrix')

# Annotate the confusion matrix with the counts
for i in range(len(LABELS)):
    for j in range(len(LABELS)):
        ax.text(j, i, format(conf_matrix[i, j], 'd'),
                ha="center", va="center",
                color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

precision, recall, f1,_ = precision_recall_fscore_support(y_test,y_pred,average='binary')
print ('Accuracy Score :',accuracy_score(error_df.true_class, y_pred) )
print ('Precision :',precision )
print ('Recall :',recall )
print ('F1 :',f1 )
# Out:
# Accuracy Score : 0.9989227040129276
# Precision : 0.9977616116396195
# Recall : 1.0
# F1 : 0.9988795518207283

# %%
from sklearn.metrics import roc_curve, auc

# Assuming y_test and reconstruction_error have been defined
fpr, tpr, thresholds = roc_curve(y_test, reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Extract the true labels and reconstruction errors from error_df
y_true = error_df['true_class']
y_scores = error_df['reconstruction_error']

# Compute the False Positive Rate (FPR) and True Positive Rate (TPR) for different thresholds
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')

# Set plot labels and title
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")

# Display the plot
plt.show()

# %%
print(f"ROC Score : {roc_auc}")
# Out:
# ROC Score : 0.9995531887225059

# %%
# If error_df.true_class is a nested structure, flatten it
y_test = error_df.true_class.apply(lambda x: int(x[0][0]) if isinstance(x, list) else int(x))

# Ensure y_pred is a list of integers
y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]

# Now calculate the metrics
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Accuracy Score:', accuracy_score(y_test, y_pred))
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy Score: 0.9989227040129276
# Precision: 0.9977616116396195
# Recall: 1.0
# F1 Score: 0.9988795518207283
