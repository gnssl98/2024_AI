# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# Out:
# 2024-12-27 08:17:41.919797: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-27 08:17:41.919886: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-27 08:17:41.919921: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-27 08:17:41.928953: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !pip install --upgrade matplotlib seaborn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/work/.local/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /home/work/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.3.post1)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Lambda, Input, Dense
from tensorflow.keras.losses import mse, binary_crossentropy, kl_divergence
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import scale


import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('../newKDDTrain+.txt', header=None)

columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
train_df.columns = columns

train_df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate    class
# 0                      0.00   normal
# 1                      0.00   normal
# 2                      0.00  anomaly
# 3                      0.01   normal
# 4                      0.00   normal
#
# [5 rows x 42 columns]

# %%
test_df = pd.read_csv('../newKDDTest+.txt', header=None)

test_columns = [
    'duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
    'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
    'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
    'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
    'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
    'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
    'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
    'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
    'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'class'
]
# Rename the columns of the DataFrame
test_df.columns = columns

test_df.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  86
# 3               0       0    0  ...                  57
# 4               0       0    0  ...                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate    class
# 0                      1.00  anomaly
# 1                      1.00  anomaly
# 2                      0.00   normal
# 3                      0.00  anomaly
# 4                      0.71  anomaly
#
# [5 rows x 42 columns]

# %%
df = pd.concat([train_df, test_df])

# %%
df['class']
# Out:
# 0         normal
# 1         normal
# 2        anomaly
# 3         normal
# 4         normal
#           ...
# 22539     normal
# 22540     normal
# 22541    anomaly
# 22542     normal
# 22543    anomaly
# Name: class, Length: 148517, dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
len(df.columns)
# Out:
# 42

# %%
df.shape
# Out:
# (148517, 42)

# %%
# 'label' 열의 값이 'normal.'이면 0으로, 'normal.'이 아니면 1로 변경
df['class'] = df['class'].apply(lambda x: 0 if x == 'normal' else 1)

# 변경된 데이터프레임 확인
print(df.head())
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding 적용
label_encoder = LabelEncoder()
df['protocol_type'] = label_encoder.fit_transform(df['protocol_type'])
df['service'] = label_encoder.fit_transform(df['service'])
df['flag'] = label_encoder.fit_transform(df['flag'])

# 인코딩된 데이터프레임 확인
print(df.head())
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       20     9        491          0     0
# 1         0              2       44     9        146          0     0
# 2         0              1       49     5          0          0     0
# 3         0              1       24     9        232       8153     0
# 4         0              1       24     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  class
# 0                      0.00      0
# 1                      0.00      0
# 2                      0.00      1
# 3                      0.01      0
# 4                      0.00      0
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (148517, 42)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

tmp = df.drop(labels = 'class',axis=1)
labels = df['class']

# 1. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(tmp)

# 2. PCA 적용 (주성분 개수 설정)
n_components = 15  # 원하는 차원 수로 설정
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)


# 3. PCA 누적 분산 비율 확인
explained_variance_ratio = pca.explained_variance_ratio_.cumsum()
print("누적 분산 비율 (cumulative explained variance):")
print(explained_variance_ratio)

# 4. PCA 결과를 DataFrame으로 변환하고 label 병합
X_pca_df = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(n_components)])
df_merged = X_pca_df.assign(label=labels.values)

# 열 이름 변경 (label -> class)
df_merged.rename(columns={'label': 'class'}, inplace=True)


# 5. 병합된 데이터 타입 확인
print("Label 데이터 타입:", df_merged['class'].dtype)

# 6. 정렬 여부 확인 (필요하면 추가)
# 확인 예시: 병합 전후 `labels` 순서와 `df_merged['label']`이 동일한지 점검
assert np.array_equal(labels.values, df_merged['class'].values), "Label 순서가 일치하지 않습니다."

# 7. PCA 결과 시각화 (2D로 줄인 경우)
import matplotlib.pyplot as plt
if n_components >= 2:
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.5)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title('PCA 결과 시각화')
    plt.colorbar(label='Label')
    plt.show()
# Out:
# 누적 분산 비율 (cumulative explained variance):
# [0.18919362 0.317851   0.38738707 0.43961021 0.48649996 0.52882681
#  0.56767508 0.60102557 0.62934237 0.65602903 0.68175061 0.70730998
#  0.7323117  0.75725748 0.78209081]
# Label 데이터 타입: int64
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#엘보우 방법
import matplotlib.pyplot as plt

# 각 주성분의 분산 비율
explained_variance_ratio = pca.explained_variance_ratio_

# 시각화
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid()
plt.show()

# %%
# 누적 분산 비율 계산
cumulative_variance_ratio = pca.explained_variance_ratio_.cumsum()

# 누적 분산 비율 출력
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio, marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance Ratio')
plt.grid()
plt.show()

# %%
# X_pca를 DataFrame으로 변환
X_pca_df = pd.DataFrame(X_pca)

# `assign`으로 label 추가
df_merged = X_pca_df.assign(label=df['class'].values)

# %%
df = df_merged

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.937410 -0.099269 -0.033749  0.114318 -0.111303  0.447596 -0.368292
# 1  0.685950  0.530799  0.084360 -0.313970  0.079048  2.455147 -3.184279
# 2  3.557238 -2.531664  0.044052  0.309757 -0.259274 -0.447251 -0.130588
# 3 -2.613555 -0.501686 -0.070464  0.034851 -0.304279 -1.015098  0.093346
# 4 -2.403520 -0.363561 -0.127547 -1.076379  0.105473 -0.663799  0.162069
#
#           7         8         9        10        11        12        13  \
# 0  0.124033  0.171330  0.210370 -0.015256  0.042213 -0.001785  0.008006
# 1  0.748932 -0.689107 -0.280753  0.056393 -0.053022 -0.034087  0.165476
# 2  0.014168  0.165737  0.092056  0.024849  0.013038  0.019188 -0.058452
# 3  0.047543  0.012064 -0.235279 -0.017312  0.033954 -0.001009  0.057715
# 4 -0.015377 -0.022084 -0.341732  0.077263 -0.000941  0.008824  0.030650
#
#          14  label
# 0 -0.106891      0
# 1  0.149943      0
# 2 -0.048249      1
# 3  0.041606      0
# 4  0.103610      0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df, test_size=0.1, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((133665, 16), (14852, 16))

# %%
X_train_normal = X_train[X_train['label'] == 0]
X_train_normal.shape

X_test_normal = X_test[X_test['label'] == 0]
X_test_normal.shape
# Out:
# (7720, 16)

# %%
y_train_normal = X_train_normal['label']
X_train_normal = X_train_normal.drop(labels='label',axis=1)

y_test_normal = X_test_normal['label']
X_test_normal = X_test_normal.drop(labels='label',axis=1)

# %%
y_test = X_test['label']
X_test = X_test.drop(labels='label', axis=1)

# %%
# !pip install keras_self_attention
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_self_attention in /home/work/.local/lib/python3.10/site-packages (0.51.0)
# Requirement already satisfied: numpy in /home/work/.local/lib/python3.10/site-packages (from keras_self_attention) (1.26.4)

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector, Conv1D, Conv1DTranspose
from keras.models import Model
from keras import regularizers
from keras_self_attention import SeqWeightedAttention, SeqSelfAttention
from keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
from tensorflow.keras import layers, losses, Model, Input
import numpy as np
from tensorflow.keras import backend as K

latent_dim = 10
inter_dim = 20

# Sampling function for reparameterization trick
def sampling(args):
    z_mean, z_log_sigma = args
    batch_size = tf.shape(z_mean)[0]
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=1.)
    return z_mean + z_log_sigma * epsilon

def vae_loss(x, x_decoded_mean, z_mean, z_log_sigma):
    reconstruction_loss = K.sum(K.square(x - x_decoded_mean), axis=1)
    kl_loss = -0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma), axis=-1)
    kl_loss_weighted = kl_loss * 0.001  # KL 다이버전스 손실에 가중치 부여
    total_loss = K.mean(reconstruction_loss + kl_loss_weighted)
    return total_loss

def cvae(X, labels):
    features = X.shape[1]  # 2D 데이터이므로 timesteps는 필요 없고, features만 사용
    input_x = Input(shape=(features,), name='InputFeatures')  # 2D 입력 (샘플, 특징)

    input_label = Input(shape=(1,), name='InputLabel')  # Assumes binary or multi-class label

    # Embed the label into the same shape as the input
    embedded_label = layers.Embedding(input_dim=2, output_dim=features)(input_label)  # Adjust output_dim to match features
    embedded_label = layers.Flatten()(embedded_label)

    # Concatenate input_x and embedded_label
    concatenated_input = layers.Concatenate()([input_x, embedded_label])

    # Reshape for Conv1D layer (to 3D)
    reshaped_input = layers.Reshape((features + embedded_label.shape[-1], 1))(concatenated_input)

    # Encoder with CNN layers
    h = layers.Conv1D(filters=64, kernel_size=3, activation="relu", padding='same')(reshaped_input)
    h = layers.Conv1D(filters=32, kernel_size=3, activation="relu", padding='same')(h)
    h = layers.Conv1D(filters=16, kernel_size=3, activation="relu", padding='same')(h)

    # Flatten for dense layers (MLP)
    h = layers.Flatten()(h)
    h = layers.Dense(inter_dim, activation='relu')(h)
    h = layers.Dense(inter_dim, activation='relu')(h)

    # z layer
    z_mean = layers.Dense(latent_dim)(h)
    z_log_sigma = layers.Dense(latent_dim)(h)
    z = layers.Lambda(sampling)([z_mean, z_log_sigma])

    # Decoder
    # Add the label to the latent space z
    z_with_label = layers.Concatenate()([z, embedded_label])

    # Expand for Conv1DTranspose layer
    decoder1 = layers.Dense((features + embedded_label.shape[-1]) * inter_dim)(z_with_label)
    decoder1 = layers.Reshape((features + embedded_label.shape[-1], inter_dim))(decoder1)

    # Decoder with CNN layers
    decoder1 = layers.Conv1DTranspose(filters=16, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=32, kernel_size=3, activation="relu", padding='same')(decoder1)
    decoder1 = layers.Conv1DTranspose(filters=64, kernel_size=3, activation="relu", padding='same')(decoder1)

    # Flatten and final dense layer to reconstruct original features
    decoder1 = layers.Flatten()(decoder1)
    decoder1 = layers.Dense(features)(decoder1)
    
    model = Model([input_x, input_label], decoder1)
    model.add_loss(vae_loss(input_x, decoder1, z_mean, z_log_sigma))
    
    return model

# Create CVAE model
model = cvae(X_train_normal, y_train_normal)
model.summary()

# Compile and train the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy'])
history = model.fit([X_train_normal, y_train_normal], X_train_normal,
                    shuffle=True,
                    epochs=200, 
                    validation_split=0.1,  
                    batch_size=32).history
# Out:
# 2024-12-27 08:17:58.480455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:c8:00.0, compute capability: 8.0
# 2024-12-27 08:17:58.482749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38698 MB memory:  -> device: 1, name: CUDA GPU, pci bus id: 0000:cc:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  InputLabel (InputLayer)     [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 15)                30        ['InputLabel[0][0]']
#
#  InputFeatures (InputLayer)  [(None, 15)]                 0         []
#
#  flatten (Flatten)           (None, 15)                   0         ['embedding[0][0]']
#
#  concatenate (Concatenate)   (None, 30)                   0         ['InputFeatures[0][0]',
#                                                                      'flatten[0][0]']
#
#  reshape (Reshape)           (None, 30, 1)                0         ['concatenate[0][0]']
#
#  conv1d (Conv1D)             (None, 30, 64)               256       ['reshape[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 30, 32)               6176      ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 30, 16)               1552      ['conv1d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 480)                  0         ['conv1d_2[0][0]']
#
#  dense (Dense)               (None, 20)                   9620      ['flatten_1[0][0]']
#
#  dense_1 (Dense)             (None, 20)                   420       ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 10)                   210       ['dense_1[0][0]']
#
#  lambda (Lambda)             (None, 10)                   0         ['dense_2[0][0]',
#                                                                      'dense_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 25)                   0         ['lambda[0][0]',
#  )                                                                   'flatten[0][0]']
#
#  dense_4 (Dense)             (None, 600)                  15600     ['concatenate_1[0][0]']
#
#  reshape_1 (Reshape)         (None, 30, 20)               0         ['dense_4[0][0]']
#
#  conv1d_transpose (Conv1DTr  (None, 30, 16)               976       ['reshape_1[0][0]']
#  anspose)
#
#  conv1d_transpose_1 (Conv1D  (None, 30, 32)               1568      ['conv1d_transpose[0][0]']
#  Transpose)
#
#  conv1d_transpose_2 (Conv1D  (None, 30, 64)               6208      ['conv1d_transpose_1[0][0]']
#  Transpose)
#
#  flatten_2 (Flatten)         (None, 1920)                 0         ['conv1d_transpose_2[0][0]']
#
#  dense_5 (Dense)             (None, 15)                   28815     ['flatten_2[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 10)                   0         ['dense_3[0][0]']
#  Lambda)
#
#  tf.math.square_1 (TFOpLamb  (None, 10)                   0         ['dense_2[0][0]']
#  da)
#
#  tf.math.subtract_1 (TFOpLa  (None, 10)                   0         ['tf.__operators__.add[0][0]',
#  mbda)                                                               'tf.math.square_1[0][0]']
#
#  tf.math.exp (TFOpLambda)    (None, 10)                   0         ['dense_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 10)                   0         ['tf.math.subtract_1[0][0]',
#  mbda)                                                               'tf.math.exp[0][0]']
#
#  tf.math.subtract (TFOpLamb  (None, 15)                   0         ['InputFeatures[0][0]',
#  da)                                                                 'dense_5[0][0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None,)                      0         ['tf.math.subtract_2[0][0]']
#  Lambda)
#
#  tf.math.square (TFOpLambda  (None, 15)                   0         ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.math.reduce_sum_1[0][0]']
#  da)
#
#  tf.math.reduce_sum (TFOpLa  (None,)                      0         ['tf.math.square[0][0]']
#  mbda)
#
#  tf.math.multiply_1 (TFOpLa  (None,)                      0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.__operators__.add_1 (TF  (None,)                      0         ['tf.math.reduce_sum[0][0]',
#  OpLambda)                                                           'tf.math.multiply_1[0][0]']
#
#  tf.math.reduce_mean (TFOpL  ()                           0         ['tf.__operators__.add_1[0][0]
#  ambda)                                                             ']
#
#  add_loss (AddLoss)          ()                           0         ['tf.math.reduce_mean[0][0]']
#
# ==================================================================================================
# Total params: 71641 (279.85 KB)
# Trainable params: 71641 (279.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 2024-12-27 08:18:00.708063: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-12-27 08:18:01.300423: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f29fec91d70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-27 08:18:01.300475: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2024-12-27 08:18:01.300482: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): CUDA GPU, Compute Capability 8.0
# 2024-12-27 08:18:01.305562: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-27 08:18:01.384304: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1950/1950 [==============================] - 15s 6ms/step - loss: 9.9503 - accuracy: 0.5641 - val_loss: 1.2799 - val_accuracy: 0.5686
# Epoch 2/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.6717 - accuracy: 0.6499 - val_loss: 0.7015 - val_accuracy: 0.7247
# Epoch 3/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 81142.1328 - accuracy: 0.6486 - val_loss: 1.3165 - val_accuracy: 0.5753
# Epoch 4/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 8.3697 - accuracy: 0.6673 - val_loss: 0.6529 - val_accuracy: 0.6069
# Epoch 5/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3505 - accuracy: 0.7190 - val_loss: 0.4773 - val_accuracy: 0.7902
# Epoch 6/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.1888 - accuracy: 0.7544 - val_loss: 0.4383 - val_accuracy: 0.7015
# Epoch 7/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.9720 - accuracy: 0.7805 - val_loss: 0.3709 - val_accuracy: 0.8059
# Epoch 8/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8929 - accuracy: 0.7474 - val_loss: 0.3660 - val_accuracy: 0.8254
# Epoch 9/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2365 - accuracy: 0.7633 - val_loss: 0.4448 - val_accuracy: 0.7632
# Epoch 10/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 4.1058 - accuracy: 0.7683 - val_loss: 0.2476 - val_accuracy: 0.8484
# Epoch 11/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2322 - accuracy: 0.8202 - val_loss: 0.3266 - val_accuracy: 0.8529
# Epoch 12/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 251.4915 - accuracy: 0.7185 - val_loss: 0.2592 - val_accuracy: 0.8070
# Epoch 13/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.3509 - accuracy: 0.7510 - val_loss: 0.2803 - val_accuracy: 0.8301
# Epoch 14/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.9027 - accuracy: 0.7791 - val_loss: 0.2511 - val_accuracy: 0.7473
# Epoch 15/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.1270 - accuracy: 0.7715 - val_loss: 0.2144 - val_accuracy: 0.8559
# Epoch 16/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.0653 - accuracy: 0.7971 - val_loss: 0.3671 - val_accuracy: 0.8151
# Epoch 17/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0267 - accuracy: 0.8250 - val_loss: 0.1857 - val_accuracy: 0.8855
# Epoch 18/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 12.9014 - accuracy: 0.7678 - val_loss: 0.2995 - val_accuracy: 0.7851
# Epoch 19/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9510 - accuracy: 0.7938 - val_loss: 0.2109 - val_accuracy: 0.7632
# Epoch 20/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7113 - accuracy: 0.8315 - val_loss: 1.1473 - val_accuracy: 0.6118
# Epoch 21/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.4018 - accuracy: 0.7397 - val_loss: 0.2745 - val_accuracy: 0.7889
# Epoch 22/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.1686 - accuracy: 0.7717 - val_loss: 0.2104 - val_accuracy: 0.8383
# Epoch 23/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.9149 - accuracy: 0.8042 - val_loss: 0.2781 - val_accuracy: 0.8604
# Epoch 24/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 635.4720 - accuracy: 0.7598 - val_loss: 0.3945 - val_accuracy: 0.8167
# Epoch 25/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 18.1114 - accuracy: 0.7580 - val_loss: 0.3950 - val_accuracy: 0.7009
# Epoch 26/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4087 - accuracy: 0.7909 - val_loss: 0.2689 - val_accuracy: 0.7716
# Epoch 27/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.9749 - accuracy: 0.8140 - val_loss: 0.1954 - val_accuracy: 0.7939
# Epoch 28/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8176 - accuracy: 0.8240 - val_loss: 0.2771 - val_accuracy: 0.8608
# Epoch 29/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.4038 - accuracy: 0.8203 - val_loss: 0.1614 - val_accuracy: 0.8800
# Epoch 30/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8483 - accuracy: 0.8378 - val_loss: 0.2931 - val_accuracy: 0.8578
# Epoch 31/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4858 - accuracy: 0.8363 - val_loss: 2.2702 - val_accuracy: 0.5637
# Epoch 32/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 43.1918 - accuracy: 0.7540 - val_loss: 0.1991 - val_accuracy: 0.8836
# Epoch 33/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9976 - accuracy: 0.8092 - val_loss: 0.3693 - val_accuracy: 0.7858
# Epoch 34/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0921 - accuracy: 0.7845 - val_loss: 0.2615 - val_accuracy: 0.8399
# Epoch 35/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 51.7556 - accuracy: 0.7926 - val_loss: 0.2668 - val_accuracy: 0.8372
# Epoch 36/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.3582 - accuracy: 0.7831 - val_loss: 0.3571 - val_accuracy: 0.8078
# Epoch 37/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.3145 - accuracy: 0.7761 - val_loss: 0.4197 - val_accuracy: 0.7394
# Epoch 38/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6886 - accuracy: 0.7937 - val_loss: 0.2293 - val_accuracy: 0.8229
# Epoch 39/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6906 - accuracy: 0.8158 - val_loss: 0.3631 - val_accuracy: 0.7364
# Epoch 40/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.5929 - accuracy: 0.7927 - val_loss: 0.1689 - val_accuracy: 0.8354
# Epoch 41/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.7887 - accuracy: 0.7907 - val_loss: 0.5103 - val_accuracy: 0.7583
# Epoch 42/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7976 - accuracy: 0.7831 - val_loss: 1.4678 - val_accuracy: 0.5251
# Epoch 43/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4728 - accuracy: 0.7225 - val_loss: 0.2173 - val_accuracy: 0.7570
# Epoch 44/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.5585 - accuracy: 0.7831 - val_loss: 0.6075 - val_accuracy: 0.7665
# Epoch 45/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.2423 - accuracy: 0.7650 - val_loss: 0.5806 - val_accuracy: 0.7579
# Epoch 46/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 97.8022 - accuracy: 0.7477 - val_loss: 0.4867 - val_accuracy: 0.8111
# Epoch 47/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5379 - accuracy: 0.7880 - val_loss: 0.7360 - val_accuracy: 0.5515
# Epoch 48/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.5510 - accuracy: 0.7869 - val_loss: 0.3556 - val_accuracy: 0.8238
# Epoch 49/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5560 - accuracy: 0.8129 - val_loss: 0.1286 - val_accuracy: 0.8578
# Epoch 50/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3815 - accuracy: 0.7861 - val_loss: 0.5025 - val_accuracy: 0.7569
# Epoch 51/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.2100 - accuracy: 0.7990 - val_loss: 0.1348 - val_accuracy: 0.8566
# Epoch 52/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 1.2354 - accuracy: 0.8274 - val_loss: 5.3144 - val_accuracy: 0.5978
# Epoch 53/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4983 - accuracy: 0.7875 - val_loss: 0.2093 - val_accuracy: 0.8699
# Epoch 54/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3406 - accuracy: 0.8171 - val_loss: 0.2084 - val_accuracy: 0.8525
# Epoch 55/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.3289 - accuracy: 0.8035 - val_loss: 0.1722 - val_accuracy: 0.8864
# Epoch 56/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6364 - accuracy: 0.8150 - val_loss: 0.2134 - val_accuracy: 0.8222
# Epoch 57/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.6691 - accuracy: 0.8262 - val_loss: 0.1371 - val_accuracy: 0.8869
# Epoch 58/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.3951 - accuracy: 0.8528 - val_loss: 0.7083 - val_accuracy: 0.8354
# Epoch 59/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4189 - accuracy: 0.7999 - val_loss: 0.1985 - val_accuracy: 0.8437
# Epoch 60/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.6905 - accuracy: 0.8084 - val_loss: 0.1978 - val_accuracy: 0.8536
# Epoch 61/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.2627 - accuracy: 0.8039 - val_loss: 0.2342 - val_accuracy: 0.8639
# Epoch 62/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7496 - accuracy: 0.8029 - val_loss: 0.2179 - val_accuracy: 0.8491
# Epoch 63/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.8986 - accuracy: 0.7837 - val_loss: 0.6144 - val_accuracy: 0.7426
# Epoch 64/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9590 - accuracy: 0.8013 - val_loss: 0.1464 - val_accuracy: 0.8712
# Epoch 65/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 29377.5508 - accuracy: 0.7830 - val_loss: 0.2278 - val_accuracy: 0.8793
# Epoch 66/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.7199 - accuracy: 0.8230 - val_loss: 0.1497 - val_accuracy: 0.8419
# Epoch 67/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7502 - accuracy: 0.8105 - val_loss: 1.9151 - val_accuracy: 0.7434
# Epoch 68/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.9380 - accuracy: 0.8434 - val_loss: 0.1160 - val_accuracy: 0.8868
# Epoch 69/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.1070 - accuracy: 0.8404 - val_loss: 0.3459 - val_accuracy: 0.8641
# Epoch 70/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.3695 - accuracy: 0.8128 - val_loss: 0.1208 - val_accuracy: 0.8538
# Epoch 71/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.3791 - accuracy: 0.8379 - val_loss: 0.1927 - val_accuracy: 0.7312
# Epoch 72/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.6025 - accuracy: 0.8176 - val_loss: 0.1173 - val_accuracy: 0.8879
# Epoch 73/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.7013 - accuracy: 0.8498 - val_loss: 0.3248 - val_accuracy: 0.8470
# Epoch 74/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.3325 - accuracy: 0.8307 - val_loss: 0.1100 - val_accuracy: 0.8679
# Epoch 75/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4057 - accuracy: 0.8073 - val_loss: 0.1083 - val_accuracy: 0.7926
# Epoch 76/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0869 - accuracy: 0.8198 - val_loss: 0.1536 - val_accuracy: 0.8992
# Epoch 77/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.2962 - accuracy: 0.8266 - val_loss: 0.2162 - val_accuracy: 0.8406
# Epoch 78/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2809 - accuracy: 0.8018 - val_loss: 0.1865 - val_accuracy: 0.7589
# Epoch 79/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.6524 - accuracy: 0.8263 - val_loss: 0.5689 - val_accuracy: 0.8324
# Epoch 80/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.9013 - accuracy: 0.8125 - val_loss: 0.7023 - val_accuracy: 0.7871
# Epoch 81/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6909 - accuracy: 0.8074 - val_loss: 0.3171 - val_accuracy: 0.8611
# Epoch 82/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.8693 - accuracy: 0.8122 - val_loss: 0.2317 - val_accuracy: 0.8282
# Epoch 83/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5017 - accuracy: 0.8423 - val_loss: 0.2951 - val_accuracy: 0.6547
# Epoch 84/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4282 - accuracy: 0.8050 - val_loss: 0.1499 - val_accuracy: 0.8457
# Epoch 85/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8948 - accuracy: 0.8277 - val_loss: 0.2433 - val_accuracy: 0.8639
# Epoch 86/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4904 - accuracy: 0.8031 - val_loss: 0.1320 - val_accuracy: 0.8429
# Epoch 87/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.0933 - accuracy: 0.7976 - val_loss: 0.1122 - val_accuracy: 0.8967
# Epoch 88/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7027 - accuracy: 0.8331 - val_loss: 0.1664 - val_accuracy: 0.8969
# Epoch 89/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4632 - accuracy: 0.7735 - val_loss: 0.1354 - val_accuracy: 0.8300
# Epoch 90/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0418 - accuracy: 0.8119 - val_loss: 1.4405 - val_accuracy: 0.4573
# Epoch 91/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.5954 - accuracy: 0.7908 - val_loss: 0.2110 - val_accuracy: 0.8591
# Epoch 92/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4232 - accuracy: 0.8213 - val_loss: 0.1466 - val_accuracy: 0.9076
# Epoch 93/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6500 - accuracy: 0.8208 - val_loss: 0.1308 - val_accuracy: 0.9191
# Epoch 94/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.0394 - accuracy: 0.7939 - val_loss: 0.1179 - val_accuracy: 0.8734
# Epoch 95/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1059 - accuracy: 0.7888 - val_loss: 0.3564 - val_accuracy: 0.6514
# Epoch 96/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1220 - accuracy: 0.7710 - val_loss: 0.1732 - val_accuracy: 0.8517
# Epoch 97/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.8465 - accuracy: 0.7821 - val_loss: 0.9490 - val_accuracy: 0.5320
# Epoch 98/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.2189 - accuracy: 0.7940 - val_loss: 0.2434 - val_accuracy: 0.7476
# Epoch 99/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5521 - accuracy: 0.8178 - val_loss: 0.1914 - val_accuracy: 0.8787
# Epoch 100/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.6696 - accuracy: 0.8017 - val_loss: 3.1088 - val_accuracy: 0.4840
# Epoch 101/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2696 - accuracy: 0.7538 - val_loss: 0.4309 - val_accuracy: 0.7159
# Epoch 102/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.5152 - accuracy: 0.8100 - val_loss: 0.1714 - val_accuracy: 0.8794
# Epoch 103/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.9082 - accuracy: 0.8036 - val_loss: 0.1491 - val_accuracy: 0.7916
# Epoch 104/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0686 - accuracy: 0.8113 - val_loss: 0.2622 - val_accuracy: 0.7938
# Epoch 105/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.1409 - accuracy: 0.8032 - val_loss: 0.2886 - val_accuracy: 0.6855
# Epoch 106/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7000 - accuracy: 0.8092 - val_loss: 0.5213 - val_accuracy: 0.8484
# Epoch 107/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.5437 - accuracy: 0.8026 - val_loss: 0.2876 - val_accuracy: 0.7903
# Epoch 108/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5460 - accuracy: 0.8242 - val_loss: 0.3406 - val_accuracy: 0.7776
# Epoch 109/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2210 - accuracy: 0.7707 - val_loss: 0.1677 - val_accuracy: 0.8287
# Epoch 110/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5340 - accuracy: 0.7952 - val_loss: 0.4431 - val_accuracy: 0.7172
# Epoch 111/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7100 - accuracy: 0.7812 - val_loss: 0.2766 - val_accuracy: 0.7427
# Epoch 112/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4675 - accuracy: 0.7845 - val_loss: 0.2619 - val_accuracy: 0.7907
# Epoch 113/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.2751 - accuracy: 0.8163 - val_loss: 0.7484 - val_accuracy: 0.7625
# Epoch 114/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8900 - accuracy: 0.8253 - val_loss: 0.1629 - val_accuracy: 0.8786
# Epoch 115/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7540 - accuracy: 0.8293 - val_loss: 0.2052 - val_accuracy: 0.7942
# Epoch 116/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 3.0669 - accuracy: 0.8059 - val_loss: 0.3590 - val_accuracy: 0.8828
# Epoch 117/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9520 - accuracy: 0.8161 - val_loss: 0.5413 - val_accuracy: 0.7381
# Epoch 118/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.4962 - accuracy: 0.8284 - val_loss: 1.4148 - val_accuracy: 0.8069
# Epoch 119/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4427 - accuracy: 0.7790 - val_loss: 0.2875 - val_accuracy: 0.8917
# Epoch 120/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9173 - accuracy: 0.7992 - val_loss: 0.1272 - val_accuracy: 0.8807
# Epoch 121/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 54.8442 - accuracy: 0.8277 - val_loss: 0.1969 - val_accuracy: 0.7701
# Epoch 122/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.9846 - accuracy: 0.7892 - val_loss: 0.1271 - val_accuracy: 0.8509
# Epoch 123/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.5718 - accuracy: 0.8140 - val_loss: 0.2456 - val_accuracy: 0.6037
# Epoch 124/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.5071 - accuracy: 0.7951 - val_loss: 0.1584 - val_accuracy: 0.7866
# Epoch 125/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.1953 - accuracy: 0.8000 - val_loss: 0.1439 - val_accuracy: 0.8666
# Epoch 126/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.4496 - accuracy: 0.8098 - val_loss: 0.2220 - val_accuracy: 0.8569
# Epoch 127/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.6357 - accuracy: 0.7841 - val_loss: 0.2020 - val_accuracy: 0.6063
# Epoch 128/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 7.5034 - accuracy: 0.7588 - val_loss: 0.3963 - val_accuracy: 0.5927
# Epoch 129/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8329 - accuracy: 0.7884 - val_loss: 0.2392 - val_accuracy: 0.8207
# Epoch 130/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.5442 - accuracy: 0.7806 - val_loss: 0.1405 - val_accuracy: 0.8830
# Epoch 131/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9574 - accuracy: 0.8060 - val_loss: 0.3256 - val_accuracy: 0.7059
# Epoch 132/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7637 - accuracy: 0.7735 - val_loss: 0.3141 - val_accuracy: 0.7884
# Epoch 133/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.0577 - accuracy: 0.7335 - val_loss: 0.2475 - val_accuracy: 0.7227
# Epoch 134/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.5624 - accuracy: 0.7628 - val_loss: 0.2511 - val_accuracy: 0.8303
# Epoch 135/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.3498 - accuracy: 0.7827 - val_loss: 0.1385 - val_accuracy: 0.8349
# Epoch 136/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6020 - accuracy: 0.7788 - val_loss: 1.6007 - val_accuracy: 0.6160
# Epoch 137/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0903 - accuracy: 0.7707 - val_loss: 0.8770 - val_accuracy: 0.8091
# Epoch 138/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.3884 - accuracy: 0.7556 - val_loss: 2.9774 - val_accuracy: 0.5449
# Epoch 139/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0900 - accuracy: 0.7829 - val_loss: 0.2213 - val_accuracy: 0.8323
# Epoch 140/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7060 - accuracy: 0.7875 - val_loss: 0.2014 - val_accuracy: 0.8313
# Epoch 141/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.1136 - accuracy: 0.7903 - val_loss: 0.1373 - val_accuracy: 0.9110
# Epoch 142/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.5969 - accuracy: 0.7970 - val_loss: 0.2337 - val_accuracy: 0.7592
# Epoch 143/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.4716 - accuracy: 0.7807 - val_loss: 0.4616 - val_accuracy: 0.7143
# Epoch 144/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1677 - accuracy: 0.7705 - val_loss: 0.2273 - val_accuracy: 0.8764
# Epoch 145/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4729 - accuracy: 0.7821 - val_loss: 0.1341 - val_accuracy: 0.8428
# Epoch 146/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6680 - accuracy: 0.7881 - val_loss: 0.3435 - val_accuracy: 0.8013
# Epoch 147/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.8217 - accuracy: 0.7880 - val_loss: 0.4745 - val_accuracy: 0.8784
# Epoch 148/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0063 - accuracy: 0.8016 - val_loss: 3.3289 - val_accuracy: 0.6035
# Epoch 149/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.8986 - accuracy: 0.7873 - val_loss: 0.2076 - val_accuracy: 0.8239
# Epoch 150/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 52.8094 - accuracy: 0.8388 - val_loss: 0.1182 - val_accuracy: 0.9008
# Epoch 151/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.1675 - accuracy: 0.8652 - val_loss: 0.1163 - val_accuracy: 0.8877
# Epoch 152/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.3973 - accuracy: 0.8511 - val_loss: 0.1197 - val_accuracy: 0.8166
# Epoch 153/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.4539 - accuracy: 0.8299 - val_loss: 0.1149 - val_accuracy: 0.8189
# Epoch 154/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.3176 - accuracy: 0.8157 - val_loss: 1.2801 - val_accuracy: 0.6974
# Epoch 155/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.0695 - accuracy: 0.7917 - val_loss: 0.1884 - val_accuracy: 0.8721
# Epoch 156/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8467 - accuracy: 0.8225 - val_loss: 0.3509 - val_accuracy: 0.8705
# Epoch 157/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.4602 - accuracy: 0.8031 - val_loss: 0.1574 - val_accuracy: 0.6780
# Epoch 158/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.5354 - accuracy: 0.8146 - val_loss: 0.3206 - val_accuracy: 0.6806
# Epoch 159/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 3.2917 - accuracy: 0.7733 - val_loss: 0.1094 - val_accuracy: 0.8960
# Epoch 160/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.2667 - accuracy: 0.7964 - val_loss: 0.1186 - val_accuracy: 0.8699
# Epoch 161/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8246 - accuracy: 0.8217 - val_loss: 0.4230 - val_accuracy: 0.6901
# Epoch 162/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.7080 - accuracy: 0.7948 - val_loss: 0.1474 - val_accuracy: 0.8510
# Epoch 163/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.6579 - accuracy: 0.7867 - val_loss: 0.1985 - val_accuracy: 0.8321
# Epoch 164/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.7607 - accuracy: 0.8407 - val_loss: 0.1390 - val_accuracy: 0.8464
# Epoch 165/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 0.6605 - accuracy: 0.8167 - val_loss: 0.1689 - val_accuracy: 0.8846
# Epoch 166/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 3.2886 - accuracy: 0.7728 - val_loss: 0.1882 - val_accuracy: 0.8150
# Epoch 167/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.4190 - accuracy: 0.7980 - val_loss: 0.1429 - val_accuracy: 0.7727
# Epoch 168/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.8660 - accuracy: 0.7892 - val_loss: 0.1810 - val_accuracy: 0.8396
# Epoch 169/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 9.8868 - accuracy: 0.7889 - val_loss: 0.2613 - val_accuracy: 0.7946
# Epoch 170/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.2841 - accuracy: 0.8254 - val_loss: 0.2373 - val_accuracy: 0.6755
# Epoch 171/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5083 - accuracy: 0.8067 - val_loss: 0.1603 - val_accuracy: 0.8453
# Epoch 172/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.7736 - accuracy: 0.7871 - val_loss: 0.2146 - val_accuracy: 0.8213
# Epoch 173/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.9274 - accuracy: 0.8062 - val_loss: 0.1810 - val_accuracy: 0.8787
# Epoch 174/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.8291 - accuracy: 0.7705 - val_loss: 0.2776 - val_accuracy: 0.7566
# Epoch 175/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 14.7164 - accuracy: 0.7758 - val_loss: 0.1766 - val_accuracy: 0.7243
# Epoch 176/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.5704 - accuracy: 0.8050 - val_loss: 0.1308 - val_accuracy: 0.8422
# Epoch 177/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.2091 - accuracy: 0.8016 - val_loss: 0.1815 - val_accuracy: 0.8558
# Epoch 178/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.6031 - accuracy: 0.8155 - val_loss: 0.2403 - val_accuracy: 0.8076
# Epoch 179/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.9244 - accuracy: 0.7819 - val_loss: 0.1522 - val_accuracy: 0.8646
# Epoch 180/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6357 - accuracy: 0.7896 - val_loss: 0.1510 - val_accuracy: 0.7139
# Epoch 181/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.0282 - accuracy: 0.7925 - val_loss: 0.1207 - val_accuracy: 0.8797
# Epoch 182/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.5261 - accuracy: 0.7739 - val_loss: 0.2693 - val_accuracy: 0.8193
# Epoch 183/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.0117 - accuracy: 0.7933 - val_loss: 0.2351 - val_accuracy: 0.8168
# Epoch 184/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 9.4909 - accuracy: 0.8203 - val_loss: 0.1391 - val_accuracy: 0.9024
# Epoch 185/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.0002 - accuracy: 0.8481 - val_loss: 0.1933 - val_accuracy: 0.8702
# Epoch 186/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.4828 - accuracy: 0.8192 - val_loss: 0.1593 - val_accuracy: 0.8033
# Epoch 187/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.0452 - accuracy: 0.8167 - val_loss: 0.1894 - val_accuracy: 0.8255
# Epoch 188/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.7162 - accuracy: 0.8089 - val_loss: 0.1726 - val_accuracy: 0.8494
# Epoch 189/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.6840 - accuracy: 0.7849 - val_loss: 0.1658 - val_accuracy: 0.8692
# Epoch 190/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.9620 - accuracy: 0.8100 - val_loss: 0.1857 - val_accuracy: 0.8777
# Epoch 191/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.7862 - accuracy: 0.8188 - val_loss: 0.1375 - val_accuracy: 0.8405
# Epoch 192/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 1.7404 - accuracy: 0.7900 - val_loss: 0.4082 - val_accuracy: 0.8265
# Epoch 193/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.5335 - accuracy: 0.7928 - val_loss: 0.1355 - val_accuracy: 0.8745
# Epoch 194/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 0.9964 - accuracy: 0.7652 - val_loss: 0.1732 - val_accuracy: 0.8826
# Epoch 195/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 5.0627 - accuracy: 0.7685 - val_loss: 0.2921 - val_accuracy: 0.7643
# Epoch 196/200
# 1950/1950 [==============================] - 11s 6ms/step - loss: 2.5292 - accuracy: 0.7999 - val_loss: 0.3958 - val_accuracy: 0.6842
# Epoch 197/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 0.6485 - accuracy: 0.8245 - val_loss: 1.0108 - val_accuracy: 0.4559
# Epoch 198/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 2.1051 - accuracy: 0.7848 - val_loss: 0.4082 - val_accuracy: 0.7646
# Epoch 199/200
# 1950/1950 [==============================] - 10s 5ms/step - loss: 2.8482 - accuracy: 0.7910 - val_loss: 0.4625 - val_accuracy: 0.6494
# Epoch 200/200
# 1950/1950 [==============================] - 11s 5ms/step - loss: 1.8119 - accuracy: 0.7452 - val_loss: 0.2559 - val_accuracy: 0.7103

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
def flatten(X):
    flattened_X = np.empty((X.shape[0], X.shape[2]))  # sample x features array.
    for i in range(X.shape[0]):
        flattened_X[i] = X[i, (X.shape[1]-1), :]
    return(flattened_X)

# %%
X_test.shape
# Out:
# (14852, 15)

# %%
valid_x_predictions = model.predict([X_test, y_test])
#mse = np.mean(np.power(flatten(test_X_selected) - flatten(valid_x_predictions), 2), axis=1)

mse = np.mean(np.power(X_test - valid_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test.tolist()})
# Out:
# 465/465 [==============================] - 1s 2ms/step

# %%
error_df
# Out:
#         reconstruction_error  true_class
# 38166               0.005512           0
# 122124              0.001558           0
# 137236              0.001303           0
# 59637               0.002621           0
# 117914             20.720549           1
# ...                      ...         ...
# 30563              19.515920           1
# 148505              0.001758           0
# 125705             22.300945           1
# 132943              0.007492           0
# 49983              27.275454           1
#
# [14852 rows x 2 columns]

# %%
error_df['true_class'].value_counts()
# Out:
# 0    7720
# 1    7132
# Name: true_class, dtype: int64

# %%
import matplotlib.pyplot as plt

# 데이터프레임 준비
true_class = error_df['true_class'].astype(str)
reconstruction_error = error_df['reconstruction_error']

# 박스 플롯 그리기
plt.figure(figsize=(8, 8))
plt.boxplot(
    [reconstruction_error[true_class == cls] for cls in sorted(true_class.unique())],
    labels=sorted(true_class.unique()),
    showfliers=False,
    vert=True,
    patch_artist=True
)

plt.ylabel('Distribution')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_19305/349485020.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
print(error_df)
# Out:
#         reconstruction_error  true_class
# 38166               0.005512           0
# 122124              0.001558           0
# 137236              0.001303           0
# 59637               0.002621           0
# 117914             20.720549           1
# ...                      ...         ...
# 30563              19.515920           1
# 148505              0.001758           0
# 125705             22.300945           1
# 132943              0.007492           0
# 49983              27.275454           1
#
# [14852 rows x 2 columns]

# %%
print(error_df[(error_df['reconstruction_error'] >= 3) & (error_df['true_class'] == 0)].count())
# Out:
# reconstruction_error    15
# true_class              15
# dtype: int64

# %%
print(error_df[(error_df['reconstruction_error'] < 3) & (error_df['true_class'] == 1)].count())
# Out:
# reconstruction_error    0
# true_class              0
# dtype: int64

# %%
# 그래프 보고 threshold 결정
threshold = 0.4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes with a specified y-axis limit
plt.figure(figsize=(8, 6))

# Add jitter to avoid overlapping points in the scatter plot
x_0 = np.random.normal(1, 0.04, size=len(true_class_0))  # Jitter for class 0
x_1 = np.random.normal(2, 0.04, size=len(true_class_1))  # Jitter for class 1

# Create the scatter plot
plt.scatter(x_0, true_class_0, color='orange', alpha=0.6, edgecolor='black', label='Class 0')
plt.scatter(x_1, true_class_1, color='blue', alpha=0.6, edgecolor='black', label='Class 1')

# Set y-axis limit
plt.ylim(0, 4)

# Set x-axis labels and adjust ticks
plt.xticks([1, 2], ['0', '1'])
plt.xlabel('True Class')

# Set y-axis label and title
plt.ylabel('Reconstruction Error')
plt.title('Reconstruction Error by True Class')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data for plotting
true_class_0 = error_df[error_df['true_class'] == 0]['reconstruction_error']
true_class_1 = error_df[error_df['true_class'] == 1]['reconstruction_error']

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 8))

# Create a swarm plot equivalent using scatter plot with more jitter
x_0 = np.random.normal(1, 0.1, size=len(true_class_0))  # Increased jitter for class 0
x_1 = np.random.normal(2, 0.1, size=len(true_class_1))  # Increased jitter for class 1

ax.scatter(x_0, true_class_0, color='blue', alpha=0.6, label='Class 0', edgecolor='w', s=50)
ax.scatter(x_1, true_class_1, color='orange', alpha=0.6, label='Class 1', edgecolor='w', s=50)

# Create boxplots
ax.boxplot([true_class_0, true_class_1], positions=[1, 2], widths=0.6, patch_artist=True, 
           showfliers=False, boxprops=dict(facecolor='None', color='black'),
           medianprops=dict(color='black'), whiskerprops=dict(color='black'))

# Set x-axis labels
ax.set_xticks([1, 2])
ax.set_xticklabels(['Class 0', 'Class 1'])

# Add a horizontal line at the threshold
ax.axhline(y=0.03, xmin=0.0, xmax=1, dashes=(5, 5), color='red')

# Adjust y-axis limit to make sure the threshold line is visible
#ax.set_ylim(bottom=min(min(true_class_0), min(true_class_1)) - 0.01, 
#           top=max(max(true_class_0), max(true_class_1)) + 0.01)
ax.set_ylim(bottom=0, top=10)
    
# Set labels and title
ax.set_ylabel('Reconstruction Error')
ax.set_title('Reconstruction Error by Class')

plt.show()

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='^', ms=3.5, linestyle='',
            label= "Normal" if name == 0 else "Fall")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.set_ylim(0, 4)
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
import numpy as np
from sklearn.metrics import f1_score

# Define the range of threshold values
threshold_range = np.arange(0.0001, 10, 0.001)

# List to store F1 scores for each threshold
f1_scores = []

# Loop through each threshold and calculate F1 score
for threshold in threshold_range:
    y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
    f1 = f1_score(error_df.true_class, y_pred)
    f1_scores.append(f1)

# Find the threshold with the highest F1 score
best_threshold = threshold_range[np.argmax(f1_scores)]
best_f1_score = max(f1_scores)

print(f"Best threshold: {best_threshold}")
print(f"Best F1 score: {best_f1_score}")

# Optionally, you can plot the F1 scores across the threshold range
plt.plot(threshold_range, f1_scores, marker='o')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Threshold')
plt.show()
# Out:
# Best threshold: 6.4611
# Best F1 score: 0.9997196523689375

# %%
# 그래프 보고 threshold 결정
threshold = 6.4611

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Assuming you have already defined LABELS, threshold, and y_pred

LABELS = ["Attack", "Normal"]

y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

# Create the figure and axis
plt.figure(figsize=(12, 12))
fig, ax = plt.subplots()

# Plot the confusion matrix using imshow
cax = ax.matshow(conf_matrix, cmap=plt.cm.Blues)

# Add color bar
plt.colorbar(cax)

# Set the labels for the axes
ax.set_xticks(np.arange(len(LABELS)))
ax.set_yticks(np.arange(len(LABELS)))

ax.set_xticklabels(LABELS)
ax.set_yticklabels(LABELS)

# Set labels and title
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.title('Confusion matrix')

# Annotate the confusion matrix with the counts
for i in range(len(LABELS)):
    for j in range(len(LABELS)):
        ax.text(j, i, format(conf_matrix[i, j], 'd'),
                ha="center", va="center",
                color="white" if conf_matrix[i, j] > conf_matrix.max() / 2 else "black")

plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

precision, recall, f1,_ = precision_recall_fscore_support(y_test,y_pred,average='binary')
print ('Accuracy Score :',accuracy_score(error_df.true_class, y_pred) )
print ('Precision :',precision )
print ('Recall :',recall )
print ('F1 :',f1 )
# Out:
# Accuracy Score : 0.9997306760032318
# Precision : 0.999439461883408
# Recall : 1.0
# F1 : 0.9997196523689375

# %%
from sklearn.metrics import roc_curve, auc

# Assuming y_test and reconstruction_error have been defined
fpr, tpr, thresholds = roc_curve(y_test, reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Extract the true labels and reconstruction errors from error_df
y_true = error_df['true_class']
y_scores = error_df['reconstruction_error']

# Compute the False Positive Rate (FPR) and True Positive Rate (TPR) for different thresholds
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Compute the area under the ROC curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')

# Set plot labels and title
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")

# Display the plot
plt.show()

# %%
print(f"ROC Score : {roc_auc}")
# Out:
# ROC Score : 0.9998357217997262

# %%
# If error_df.true_class is a nested structure, flatten it
y_test = error_df.true_class.apply(lambda x: int(x[0][0]) if isinstance(x, list) else int(x))

# Ensure y_pred is a list of integers
y_pred = [0 if e < threshold else 1 for e in error_df.reconstruction_error.values]

# Now calculate the metrics
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Accuracy Score:', accuracy_score(y_test, y_pred))
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy Score: 0.9997306760032318
# Precision: 0.999439461883408
# Recall: 1.0
# F1 Score: 0.9997196523689375
